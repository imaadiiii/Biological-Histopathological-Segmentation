# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, confusion_matrix
from tqdm import tqdm
import tensorflow as tf
from tensorflow import keras
import os
from tensorflow.keras import backend as K
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dropout, UpSampling2D, Input
import cv2
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, confusion_matrix
from tqdm import tqdm
import tensorflow as tf
import os
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dropout, UpSampling2D, Input
from tensorflow.keras import backend as K
from tensorflow.keras.metrics import Accuracy, Precision, Recall
import os

def lab_split(I):
    I = cv2.cvtColor(I, cv2.COLOR_BGR2LAB)
    I = I.astype(np.float32)
    I1, I2, I3 = cv2.split(I)
    I1 /= 2.55
    I2 -= 128.0
    I3 -= 128.0
    return I1, I2, I3

def merge_back(I1, I2, I3):
    I1 *= 2.55
    I2 += 128.0
    I3 += 128.0
    I = np.clip(cv2.merge((I1, I2, I3)), 0, 255).astype(np.uint8)
    return cv2.cvtColor(I, cv2.COLOR_LAB2BGR)

def get_mean_std(I):
    I1, I2, I3 = lab_split(I)
    m1, sd1 = cv2.meanStdDev(I1)
    m2, sd2 = cv2.meanStdDev(I2)
    m3, sd3 = cv2.meanStdDev(I3)
    means = m1, m2, m3
    stds = sd1, sd2, sd3
    return means, stds

def Reinhard_method(target,I):
    means, stds = get_mean_std(target)
    target_means = means
    target_stds = stds
    I1, I2, I3 = lab_split(I)
    means, stds = get_mean_std(I)
    norm1 = ((I1 - means[0]) * (target_stds[0] / stds[0])) + target_means[0]
    norm2 = ((I2 - means[1]) * (target_stds[1] / stds[1])) + target_means[1]
    norm3 = ((I3 - means[2]) * (target_stds[2] / stds[2])) + target_means[2]
    return merge_back(norm1, norm2, norm3)

def calculateClass(img,n_labels,h,w):
    lab=np.zeros([h,w])
    for i in range (h):
        for j in range (w):
            b=img[i][j][0]
            g=img[i][j][1]
            r=img[i][j][2]
            if b==229 and g==155 and r==3:
                lab[i][j]=0
            else:
                lab[i][j]=1
    return lab

def create_label(img, dims,h,w,n_labels=2):
    labels=calculateClass(img,n_labels,h,w)
    x1 = np.zeros([dims[0], dims[1], n_labels])
    for i in range(dims[0]):
        for j in range(dims[1]):
            v1=int(labels[i][j])
            x1[i][j][v1]=1
    x1 = x1.reshape(dims[0] , dims[1], n_labels)
    return x1

def Calculate_metrics(test_image, gt, h, w):
    size = len(test_image)
    h, w, _ = np.shape(test_image[0])
    y_pred = np.zeros((h * w * size, 1))
    y_test = np.zeros((h * w * size, 1))

    res_img = []

    for q in tqdm(range(size), desc="Processing images"):
        img11 = test_image[q]
        img = np.zeros((h, w, 3))
        for i in range(h):
            for j in range(w):
                c1 = img11[i][j][0]
                c2 = img11[i][j][1]
                if c1 > c2:
                    img[i][j] = [0, 0, 0]
                else:
                    img[i][j] = [255, 255, 255]
        res_img.append(img)

    res_img = np.array(res_img)
    c = 0

    for i in tqdm(range(size), desc="Calculating y_pred"):
        img = res_img[i]
        for j in range(h):
            for l in range(w):
                b = img[j][l][0]
                if b == 0:
                    y_pred[c][0] = 0
                else:
                    y_pred[c][0] = 1
                c += 1

    c = 0

    for i in tqdm(range(size), desc="Calculating y_test"):
        img = gt[i]
        for j in range(h):
            for l in range(w):
                b = img[j][l][0]
                if b == 1:
                    y_test[c][0] = 0
                else:
                    y_test[c][0] = 1
                c += 1

    print(classification_report(y_test, y_pred))

    conf_mat = confusion_matrix(y_test, y_pred, labels=[0, 1])
    tp = np.diag(conf_mat)
    fp = np.sum(conf_mat, axis=0) - tp
    fn = np.sum(conf_mat, axis=1) - tp
    iou = tp / (tp + fp + fn + 1e-10)
    miou = np.mean(iou)

    print('mIoU:', miou)
    return

def dice_coef(y_true, y_pred):
    numerator = 2 * K.sum(y_true * y_pred, axis=(1, 2, 3))
    denominator = K.sum(y_true, axis=(1, 2, 3)) + K.sum(y_pred, axis=(1, 2, 3))
    dice_loss = 1 - (numerator + 1) / (denominator + 1)
    return dice_loss

def dice_coef_loss(y_true, y_pred):
    return 1.0 - dice_coef(y_true, y_pred)

def Prepare_data(path_train, path_gt, h, w, n_labels=2):
    target = cv2.imread("/content/drive/MyDrive/Colab_Notebooks/BHI_dataset/Target.png")
    imgs = []
    labels = []

    files_train = os.listdir(path_train)
    files_gt = os.listdir(path_gt)

    base_files_train = set([os.path.splitext(file)[0] for file in files_train])
    base_files_gt = set([os.path.splitext(file)[0] for file in files_gt])

    matching_files = list(set(base_files_train).intersection(base_files_gt))

    for file_base in tqdm(matching_files):
        original_img = cv2.imread(os.path.join(path_train, file_base + ".png"))
        mask = cv2.imread(os.path.join(path_gt, file_base + ".png"))

        resized_img = cv2.resize(original_img, (h, w))
        cn_img = Reinhard_method(target, resized_img)
        array_img = img_to_array(cn_img) / 255
        imgs.append(array_img)

        mask = cv2.resize(mask, (h, w))
        array_mask = create_label(mask, (h, w),h,w,2)
        labels.append(array_mask)
    imgs = np.array(imgs)
    labels = np.array(labels)
    return imgs, labels, matching_files

# RESNET
def bn_act(x, act=True):
    x = keras.layers.BatchNormalization()(x)
    if act == True:
        x = keras.layers.Activation("relu")(x)
    return x

def conv_block(x, filters, kernel_size=(3, 3), padding="same", strides=1):
    conv = bn_act(x)
    conv = keras.layers.Conv2D(filters, kernel_size, padding=padding, strides=strides)(conv)
    return conv

def stem(x, filters, kernel_size=(3, 3), padding="same", strides=1):
    conv = keras.layers.Conv2D(filters, kernel_size, padding=padding, strides=strides)(x)
    conv = conv_block(conv, filters, kernel_size=kernel_size, padding=padding, strides=strides)

    shortcut = keras.layers.Conv2D(filters, kernel_size=(1, 1), padding=padding, strides=strides)(x)
    shortcut = bn_act(shortcut, act=False)

    output = keras.layers.Add()([conv, shortcut])
    return output

def residual_block(x, filters, kernel_size=(3, 3), padding="same", strides=1):
    res = conv_block(x, filters, kernel_size=kernel_size, padding=padding, strides=strides)
    res = conv_block(res, filters, kernel_size=kernel_size, padding=padding, strides=1)

    shortcut = keras.layers.Conv2D(filters, kernel_size=(1, 1), padding=padding, strides=strides)(x)
    shortcut = bn_act(shortcut, act=False)

    output = keras.layers.Add()([shortcut, res])
    return output

def upsample_concat_block(x, xskip):
    u = keras.layers.UpSampling2D((2, 2))(x)
    c = keras.layers.Concatenate()([u, xskip])
    return c

def ResUNet(image_size,lr):
    f = [16, 32, 64, 128, 256]
    inputs = keras.layers.Input((image_size, image_size, 3))

    ## Encoder
    e0 = inputs
    e1 = stem(e0, f[0])
    e2 = residual_block(e1, f[1], strides=2)
    e3 = residual_block(e2, f[2], strides=2)
    e4 = residual_block(e3, f[3], strides=2)
    e5 = residual_block(e4, f[4], strides=2)

    ## Bridge
    b0 = conv_block(e5, f[4], strides=1)
    b1 = conv_block(b0, f[4], strides=1)

    ## Decoder
    u1 = upsample_concat_block(b1, e4)
    d1 = residual_block(u1, f[4])

    u2 = upsample_concat_block(d1, e3)
    d2 = residual_block(u2, f[3])

    u3 = upsample_concat_block(d2, e2)
    d3 = residual_block(u3, f[2])

    u4 = upsample_concat_block(d3, e1)
    d4 = residual_block(u4, f[1])

    outputs = keras.layers.Conv2D(2, (1, 1), padding="same", activation="sigmoid")(d4)
    model = keras.models.Model(inputs, outputs)
    adam = keras.optimizers.Adam(learning_rate=lr)
    model.compile(optimizer=adam, loss="binary_crossentropy", metrics=["accuracy"])
    model.summary()
    return model

if __name__ == "__main__":
    path_train='/content/drive/MyDrive/Colab_Notebooks/BHI_dataset/Gt/'
    path_gt='/content/drive/MyDrive/Colab_Notebooks/BHI_dataset/Img/'

    h=256
    w=256
    lr=0.00001

    print("Preparing and loading training data...")
    X,Y,filenames = Prepare_data(path_train,path_gt,h,w)
    print("Done Preparing training data...")

    nb_epoch = 50
    batch = 5
    n_labels = 2
    model=ResUNet(h,lr)

    print('Model Compiled: OK.....')
    print("Opening model...")
    history=model.fit(x=X,y=Y,batch_size=batch, epochs=nb_epoch, verbose=1,validation_split=0.2)
    print("Model Fitting done...")
    model.save_weights('U-Net_50.hdf5')
    model.load_weights('U-Net_50.hdf5')

    fig=plt.figure()
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('Model accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()
    fig.savefig("Resnet-bc.png")
    # Summarize history for loss
    fig=plt.figure()
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('Model loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()
    fig.savefig("U-Net_loss.png")

    path_test_gt='/content/drive/MyDrive/Colab_Notebooks/BHI_dataset/Img-test/'
    path_test='/content/drive/MyDrive/Colab_Notebooks/BHI_dataset/Gt-test/'
    print("Preparing testing data...")
    test_data,gt,filenames = Prepare_data(path_test,path_test_gt,h,w)
    output = model.predict(test_data,batch_size=batch, verbose=1)

    print("Calculating metrics...")
    Calculate_metrics(output,gt,h,w)

    for i in tqdm(range(len(test_data))):
        Write_output_path = "/content/drive/MyDrive/Colab_Notebooks/BHI_dataset/Resnet/Results/Img_" + filenames[i] + ".png"
        out = output[i]
        img = test_data[i]
        for j in range(h):
            for p in range(w):
                if out[j][p][0] > out[j][p][1]:
                    img[j][p] = [0, 0, 0]
                else:
                    img[j][p] = [255, 255, 255]

        cv2.imwrite(Write_output_path, img)
# Out:
# Preparing and loading training data...
# 100%|██████████| 340/340 [02:13<00:00,  2.55it/s]
# Done Preparing training data...
# Model: "model_4"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_5 (InputLayer)        [(None, 256, 256, 3)]        0         []
#
#  conv2d_120 (Conv2D)         (None, 256, 256, 16)         448       ['input_5[0][0]']
#
#  batch_normalization_112 (B  (None, 256, 256, 16)         64        ['conv2d_120[0][0]']
#  atchNormalization)
#
#  activation_76 (Activation)  (None, 256, 256, 16)         0         ['batch_normalization_112[0][0
#                                                                     ]']
#
#  conv2d_122 (Conv2D)         (None, 256, 256, 16)         64        ['input_5[0][0]']
#
#  conv2d_121 (Conv2D)         (None, 256, 256, 16)         2320      ['activation_76[0][0]']
#
#  batch_normalization_113 (B  (None, 256, 256, 16)         64        ['conv2d_122[0][0]']
#  atchNormalization)
#
#  add_36 (Add)                (None, 256, 256, 16)         0         ['conv2d_121[0][0]',
#                                                                      'batch_normalization_113[0][0
#                                                                     ]']
#
#  batch_normalization_114 (B  (None, 256, 256, 16)         64        ['add_36[0][0]']
#  atchNormalization)
#
#  activation_77 (Activation)  (None, 256, 256, 16)         0         ['batch_normalization_114[0][0
#                                                                     ]']
#
#  conv2d_123 (Conv2D)         (None, 128, 128, 32)         4640      ['activation_77[0][0]']
#
#  batch_normalization_115 (B  (None, 128, 128, 32)         128       ['conv2d_123[0][0]']
#  atchNormalization)
#
#  conv2d_125 (Conv2D)         (None, 128, 128, 32)         544       ['add_36[0][0]']
#
#  activation_78 (Activation)  (None, 128, 128, 32)         0         ['batch_normalization_115[0][0
#                                                                     ]']
#
#  batch_normalization_116 (B  (None, 128, 128, 32)         128       ['conv2d_125[0][0]']
#  atchNormalization)
#
#  conv2d_124 (Conv2D)         (None, 128, 128, 32)         9248      ['activation_78[0][0]']
#
#  add_37 (Add)                (None, 128, 128, 32)         0         ['batch_normalization_116[0][0
#                                                                     ]',
#                                                                      'conv2d_124[0][0]']
#
#  batch_normalization_117 (B  (None, 128, 128, 32)         128       ['add_37[0][0]']
#  atchNormalization)
#
#  activation_79 (Activation)  (None, 128, 128, 32)         0         ['batch_normalization_117[0][0
#                                                                     ]']
#
#  conv2d_126 (Conv2D)         (None, 64, 64, 64)           18496     ['activation_79[0][0]']
#
#  batch_normalization_118 (B  (None, 64, 64, 64)           256       ['conv2d_126[0][0]']
#  atchNormalization)
#
#  conv2d_128 (Conv2D)         (None, 64, 64, 64)           2112      ['add_37[0][0]']
#
#  activation_80 (Activation)  (None, 64, 64, 64)           0         ['batch_normalization_118[0][0
#                                                                     ]']
#
#  batch_normalization_119 (B  (None, 64, 64, 64)           256       ['conv2d_128[0][0]']
#  atchNormalization)
#
#  conv2d_127 (Conv2D)         (None, 64, 64, 64)           36928     ['activation_80[0][0]']
#
#  add_38 (Add)                (None, 64, 64, 64)           0         ['batch_normalization_119[0][0
#                                                                     ]',
#                                                                      'conv2d_127[0][0]']
#
#  batch_normalization_120 (B  (None, 64, 64, 64)           256       ['add_38[0][0]']
#  atchNormalization)
#
#  activation_81 (Activation)  (None, 64, 64, 64)           0         ['batch_normalization_120[0][0
#                                                                     ]']
#
#  conv2d_129 (Conv2D)         (None, 32, 32, 128)          73856     ['activation_81[0][0]']
#
#  batch_normalization_121 (B  (None, 32, 32, 128)          512       ['conv2d_129[0][0]']
#  atchNormalization)
#
#  conv2d_131 (Conv2D)         (None, 32, 32, 128)          8320      ['add_38[0][0]']
#
#  activation_82 (Activation)  (None, 32, 32, 128)          0         ['batch_normalization_121[0][0
#                                                                     ]']
#
#  batch_normalization_122 (B  (None, 32, 32, 128)          512       ['conv2d_131[0][0]']
#  atchNormalization)
#
#  conv2d_130 (Conv2D)         (None, 32, 32, 128)          147584    ['activation_82[0][0]']
#
#  add_39 (Add)                (None, 32, 32, 128)          0         ['batch_normalization_122[0][0
#                                                                     ]',
#                                                                      'conv2d_130[0][0]']
#
#  batch_normalization_123 (B  (None, 32, 32, 128)          512       ['add_39[0][0]']
#  atchNormalization)
#
#  activation_83 (Activation)  (None, 32, 32, 128)          0         ['batch_normalization_123[0][0
#                                                                     ]']
#
#  conv2d_132 (Conv2D)         (None, 16, 16, 256)          295168    ['activation_83[0][0]']
#
#  batch_normalization_124 (B  (None, 16, 16, 256)          1024      ['conv2d_132[0][0]']
#  atchNormalization)
#
#  conv2d_134 (Conv2D)         (None, 16, 16, 256)          33024     ['add_39[0][0]']
#
#  activation_84 (Activation)  (None, 16, 16, 256)          0         ['batch_normalization_124[0][0
#                                                                     ]']
#
#  batch_normalization_125 (B  (None, 16, 16, 256)          1024      ['conv2d_134[0][0]']
#  atchNormalization)
#
#  conv2d_133 (Conv2D)         (None, 16, 16, 256)          590080    ['activation_84[0][0]']
#
#  add_40 (Add)                (None, 16, 16, 256)          0         ['batch_normalization_125[0][0
#                                                                     ]',
#                                                                      'conv2d_133[0][0]']
#
#  batch_normalization_126 (B  (None, 16, 16, 256)          1024      ['add_40[0][0]']
#  atchNormalization)
#
#  activation_85 (Activation)  (None, 16, 16, 256)          0         ['batch_normalization_126[0][0
#                                                                     ]']
#
#  conv2d_135 (Conv2D)         (None, 16, 16, 256)          590080    ['activation_85[0][0]']
#
#  batch_normalization_127 (B  (None, 16, 16, 256)          1024      ['conv2d_135[0][0]']
#  atchNormalization)
#
#  activation_86 (Activation)  (None, 16, 16, 256)          0         ['batch_normalization_127[0][0
#                                                                     ]']
#
#  conv2d_136 (Conv2D)         (None, 16, 16, 256)          590080    ['activation_86[0][0]']
#
#  up_sampling2d_16 (UpSampli  (None, 32, 32, 256)          0         ['conv2d_136[0][0]']
#  ng2D)
#
#  concatenate_16 (Concatenat  (None, 32, 32, 384)          0         ['up_sampling2d_16[0][0]',
#  e)                                                                  'add_39[0][0]']
#
#  batch_normalization_128 (B  (None, 32, 32, 384)          1536      ['concatenate_16[0][0]']
#  atchNormalization)
#
#  activation_87 (Activation)  (None, 32, 32, 384)          0         ['batch_normalization_128[0][0
#                                                                     ]']
#
#  conv2d_137 (Conv2D)         (None, 32, 32, 256)          884992    ['activation_87[0][0]']
#
#  batch_normalization_129 (B  (None, 32, 32, 256)          1024      ['conv2d_137[0][0]']
#  atchNormalization)
#
#  conv2d_139 (Conv2D)         (None, 32, 32, 256)          98560     ['concatenate_16[0][0]']
#
#  activation_88 (Activation)  (None, 32, 32, 256)          0         ['batch_normalization_129[0][0
#                                                                     ]']
#
#  batch_normalization_130 (B  (None, 32, 32, 256)          1024      ['conv2d_139[0][0]']
#  atchNormalization)
#
#  conv2d_138 (Conv2D)         (None, 32, 32, 256)          590080    ['activation_88[0][0]']
#
#  add_41 (Add)                (None, 32, 32, 256)          0         ['batch_normalization_130[0][0
#                                                                     ]',
#                                                                      'conv2d_138[0][0]']
#
#  up_sampling2d_17 (UpSampli  (None, 64, 64, 256)          0         ['add_41[0][0]']
#  ng2D)
#
#  concatenate_17 (Concatenat  (None, 64, 64, 320)          0         ['up_sampling2d_17[0][0]',
#  e)                                                                  'add_38[0][0]']
#
#  batch_normalization_131 (B  (None, 64, 64, 320)          1280      ['concatenate_17[0][0]']
#  atchNormalization)
#
#  activation_89 (Activation)  (None, 64, 64, 320)          0         ['batch_normalization_131[0][0
#                                                                     ]']
#
#  conv2d_140 (Conv2D)         (None, 64, 64, 128)          368768    ['activation_89[0][0]']
#
#  batch_normalization_132 (B  (None, 64, 64, 128)          512       ['conv2d_140[0][0]']
#  atchNormalization)
#
#  conv2d_142 (Conv2D)         (None, 64, 64, 128)          41088     ['concatenate_17[0][0]']
#
#  activation_90 (Activation)  (None, 64, 64, 128)          0         ['batch_normalization_132[0][0
#                                                                     ]']
#
#  batch_normalization_133 (B  (None, 64, 64, 128)          512       ['conv2d_142[0][0]']
#  atchNormalization)
#
#  conv2d_141 (Conv2D)         (None, 64, 64, 128)          147584    ['activation_90[0][0]']
#
#  add_42 (Add)                (None, 64, 64, 128)          0         ['batch_normalization_133[0][0
#                                                                     ]',
#                                                                      'conv2d_141[0][0]']
#
#  up_sampling2d_18 (UpSampli  (None, 128, 128, 128)        0         ['add_42[0][0]']
#  ng2D)
#
#  concatenate_18 (Concatenat  (None, 128, 128, 160)        0         ['up_sampling2d_18[0][0]',
#  e)                                                                  'add_37[0][0]']
#
#  batch_normalization_134 (B  (None, 128, 128, 160)        640       ['concatenate_18[0][0]']
#  atchNormalization)
#
#  activation_91 (Activation)  (None, 128, 128, 160)        0         ['batch_normalization_134[0][0
#                                                                     ]']
#
#  conv2d_143 (Conv2D)         (None, 128, 128, 64)         92224     ['activation_91[0][0]']
#
#  batch_normalization_135 (B  (None, 128, 128, 64)         256       ['conv2d_143[0][0]']
#  atchNormalization)
#
#  conv2d_145 (Conv2D)         (None, 128, 128, 64)         10304     ['concatenate_18[0][0]']
#
#  activation_92 (Activation)  (None, 128, 128, 64)         0         ['batch_normalization_135[0][0
#                                                                     ]']
#
#  batch_normalization_136 (B  (None, 128, 128, 64)         256       ['conv2d_145[0][0]']
#  atchNormalization)
#
#  conv2d_144 (Conv2D)         (None, 128, 128, 64)         36928     ['activation_92[0][0]']
#
#  add_43 (Add)                (None, 128, 128, 64)         0         ['batch_normalization_136[0][0
#                                                                     ]',
#                                                                      'conv2d_144[0][0]']
#
#  up_sampling2d_19 (UpSampli  (None, 256, 256, 64)         0         ['add_43[0][0]']
#  ng2D)
#
#  concatenate_19 (Concatenat  (None, 256, 256, 80)         0         ['up_sampling2d_19[0][0]',
#  e)                                                                  'add_36[0][0]']
#
#  batch_normalization_137 (B  (None, 256, 256, 80)         320       ['concatenate_19[0][0]']
#  atchNormalization)
#
#  activation_93 (Activation)  (None, 256, 256, 80)         0         ['batch_normalization_137[0][0
#                                                                     ]']
#
#  conv2d_146 (Conv2D)         (None, 256, 256, 32)         23072     ['activation_93[0][0]']
#
#  batch_normalization_138 (B  (None, 256, 256, 32)         128       ['conv2d_146[0][0]']
#  atchNormalization)
#
#  conv2d_148 (Conv2D)         (None, 256, 256, 32)         2592      ['concatenate_19[0][0]']
#
#  activation_94 (Activation)  (None, 256, 256, 32)         0         ['batch_normalization_138[0][0
#                                                                     ]']
#
#  batch_normalization_139 (B  (None, 256, 256, 32)         128       ['conv2d_148[0][0]']
#  atchNormalization)
#
#  conv2d_147 (Conv2D)         (None, 256, 256, 32)         9248      ['activation_94[0][0]']
#
#  add_44 (Add)                (None, 256, 256, 32)         0         ['batch_normalization_139[0][0
#                                                                     ]',
#                                                                      'conv2d_147[0][0]']
#
#  conv2d_149 (Conv2D)         (None, 256, 256, 2)          66        ['add_44[0][0]']
#
# ==================================================================================================
# Total params: 4723090 (18.02 MB)
# Trainable params: 4715794 (17.99 MB)
# Non-trainable params: 7296 (28.50 KB)
# __________________________________________________________________________________________________
# Model Compiled: OK.....
# Opening model...
# Epoch 1/50
# 55/55 [==============================] - 38s 233ms/step - loss: 0.7691 - accuracy: 0.5723 - val_loss: 0.7148 - val_accuracy: 0.5008
# Epoch 2/50
# 55/55 [==============================] - 7s 135ms/step - loss: 0.6341 - accuracy: 0.6825 - val_loss: 0.7580 - val_accuracy: 0.4839
# Epoch 3/50
# 55/55 [==============================] - 7s 136ms/step - loss: 0.5704 - accuracy: 0.7260 - val_loss: 0.8104 - val_accuracy: 0.4965
# Epoch 4/50
# 55/55 [==============================] - 7s 136ms/step - loss: 0.5272 - accuracy: 0.7536 - val_loss: 0.9159 - val_accuracy: 0.5119
# Epoch 5/50
# 55/55 [==============================] - 8s 137ms/step - loss: 0.4931 - accuracy: 0.7726 - val_loss: 0.9621 - val_accuracy: 0.5628
# Epoch 6/50
# 55/55 [==============================] - 8s 137ms/step - loss: 0.4600 - accuracy: 0.7936 - val_loss: 0.8331 - val_accuracy: 0.6440
# Epoch 7/50
# 55/55 [==============================] - 8s 138ms/step - loss: 0.4336 - accuracy: 0.8092 - val_loss: 0.8264 - val_accuracy: 0.6561
# Epoch 8/50
# 55/55 [==============================] - 7s 136ms/step - loss: 0.3932 - accuracy: 0.8305 - val_loss: 0.7102 - val_accuracy: 0.7063
# Epoch 9/50
# 55/55 [==============================] - 8s 137ms/step - loss: 0.3689 - accuracy: 0.8438 - val_loss: 0.5841 - val_accuracy: 0.7430
# Epoch 10/50
# 55/55 [==============================] - 7s 136ms/step - loss: 0.3362 - accuracy: 0.8604 - val_loss: 0.5858 - val_accuracy: 0.7523
# Epoch 11/50
# 55/55 [==============================] - 8s 141ms/step - loss: 0.3190 - accuracy: 0.8677 - val_loss: 0.5008 - val_accuracy: 0.7882
# Epoch 12/50
# 55/55 [==============================] - 8s 138ms/step - loss: 0.2836 - accuracy: 0.8860 - val_loss: 0.4448 - val_accuracy: 0.8081
# Epoch 13/50
# 55/55 [==============================] - 8s 140ms/step - loss: 0.2653 - accuracy: 0.8945 - val_loss: 0.4351 - val_accuracy: 0.8154
# Epoch 14/50
# 55/55 [==============================] - 8s 137ms/step - loss: 0.2448 - accuracy: 0.9044 - val_loss: 0.4237 - val_accuracy: 0.8210
# Epoch 15/50
# 55/55 [==============================] - 8s 142ms/step - loss: 0.2287 - accuracy: 0.9115 - val_loss: 0.4314 - val_accuracy: 0.8195
# Epoch 16/50
# 55/55 [==============================] - 8s 140ms/step - loss: 0.2112 - accuracy: 0.9195 - val_loss: 0.4217 - val_accuracy: 0.8240
# Epoch 17/50
# 55/55 [==============================] - 8s 140ms/step - loss: 0.1999 - accuracy: 0.9240 - val_loss: 0.4286 - val_accuracy: 0.8209
# Epoch 18/50
# 55/55 [==============================] - 8s 140ms/step - loss: 0.1951 - accuracy: 0.9254 - val_loss: 0.4294 - val_accuracy: 0.8252
# Epoch 19/50
# 55/55 [==============================] - 8s 143ms/step - loss: 0.1815 - accuracy: 0.9322 - val_loss: 0.4332 - val_accuracy: 0.8220
# Epoch 20/50
# 55/55 [==============================] - 8s 141ms/step - loss: 0.1742 - accuracy: 0.9341 - val_loss: 0.4741 - val_accuracy: 0.8172
# Epoch 21/50
# 55/55 [==============================] - 8s 143ms/step - loss: 0.1748 - accuracy: 0.9326 - val_loss: 0.4830 - val_accuracy: 0.8149
# Epoch 22/50
# 55/55 [==============================] - 8s 141ms/step - loss: 0.1605 - accuracy: 0.9400 - val_loss: 0.4363 - val_accuracy: 0.8267
# Epoch 23/50
# 55/55 [==============================] - 8s 143ms/step - loss: 0.1479 - accuracy: 0.9453 - val_loss: 0.4483 - val_accuracy: 0.8252
# Epoch 24/50
# 55/55 [==============================] - 8s 140ms/step - loss: 0.1548 - accuracy: 0.9420 - val_loss: 0.4590 - val_accuracy: 0.8196
# Epoch 25/50
# 55/55 [==============================] - 8s 140ms/step - loss: 0.1497 - accuracy: 0.9444 - val_loss: 0.4529 - val_accuracy: 0.8225
# Epoch 26/50
# 55/55 [==============================] - 8s 142ms/step - loss: 0.1403 - accuracy: 0.9473 - val_loss: 0.4725 - val_accuracy: 0.8183
# Epoch 27/50
# 55/55 [==============================] - 8s 141ms/step - loss: 0.1317 - accuracy: 0.9510 - val_loss: 0.4513 - val_accuracy: 0.8250
# Epoch 28/50
# 55/55 [==============================] - 8s 143ms/step - loss: 0.1189 - accuracy: 0.9560 - val_loss: 0.4411 - val_accuracy: 0.8296
# Epoch 29/50
# 55/55 [==============================] - 8s 140ms/step - loss: 0.1266 - accuracy: 0.9529 - val_loss: 0.4574 - val_accuracy: 0.8264
# Epoch 30/50
# 55/55 [==============================] - 8s 143ms/step - loss: 0.1187 - accuracy: 0.9559 - val_loss: 0.4571 - val_accuracy: 0.8269
# Epoch 31/50
# 55/55 [==============================] - 8s 142ms/step - loss: 0.1176 - accuracy: 0.9564 - val_loss: 0.4696 - val_accuracy: 0.8253
# Epoch 32/50
# 55/55 [==============================] - 8s 143ms/step - loss: 0.1117 - accuracy: 0.9585 - val_loss: 0.4750 - val_accuracy: 0.8244
# Epoch 33/50
# 55/55 [==============================] - 8s 140ms/step - loss: 0.1103 - accuracy: 0.9587 - val_loss: 0.4594 - val_accuracy: 0.8272
# Epoch 34/50
# 55/55 [==============================] - 8s 144ms/step - loss: 0.1079 - accuracy: 0.9600 - val_loss: 0.4701 - val_accuracy: 0.8275
# Epoch 35/50
# 55/55 [==============================] - 8s 140ms/step - loss: 0.1099 - accuracy: 0.9587 - val_loss: 0.4783 - val_accuracy: 0.8225
# Epoch 36/50
# 55/55 [==============================] - 8s 143ms/step - loss: 0.1089 - accuracy: 0.9588 - val_loss: 0.4989 - val_accuracy: 0.8221
# Epoch 37/50
# 55/55 [==============================] - 8s 142ms/step - loss: 0.1063 - accuracy: 0.9601 - val_loss: 0.4708 - val_accuracy: 0.8287
# Epoch 38/50
# 55/55 [==============================] - 8s 142ms/step - loss: 0.0973 - accuracy: 0.9635 - val_loss: 0.4763 - val_accuracy: 0.8288
# Epoch 39/50
# 55/55 [==============================] - 8s 140ms/step - loss: 0.0984 - accuracy: 0.9628 - val_loss: 0.5175 - val_accuracy: 0.8145
# Epoch 40/50
# 55/55 [==============================] - 8s 145ms/step - loss: 0.0932 - accuracy: 0.9650 - val_loss: 0.4756 - val_accuracy: 0.8294
# Epoch 41/50
# 55/55 [==============================] - 8s 141ms/step - loss: 0.0910 - accuracy: 0.9656 - val_loss: 0.4818 - val_accuracy: 0.8309
# Epoch 42/50
# 55/55 [==============================] - 8s 143ms/step - loss: 0.0902 - accuracy: 0.9658 - val_loss: 0.4983 - val_accuracy: 0.8250
# Epoch 43/50
# 55/55 [==============================] - 8s 146ms/step - loss: 0.0947 - accuracy: 0.9637 - val_loss: 0.5246 - val_accuracy: 0.8184
# Epoch 44/50
# 55/55 [==============================] - 8s 142ms/step - loss: 0.0908 - accuracy: 0.9657 - val_loss: 0.5104 - val_accuracy: 0.8251
# Epoch 45/50
# 55/55 [==============================] - 8s 143ms/step - loss: 0.0885 - accuracy: 0.9666 - val_loss: 0.5040 - val_accuracy: 0.8305
# Epoch 46/50
# 55/55 [==============================] - 8s 144ms/step - loss: 0.1092 - accuracy: 0.9582 - val_loss: 0.5372 - val_accuracy: 0.8199
# Epoch 47/50
# 55/55 [==============================] - 8s 142ms/step - loss: 0.0926 - accuracy: 0.9646 - val_loss: 0.5187 - val_accuracy: 0.8260
# Epoch 48/50
# 55/55 [==============================] - 8s 141ms/step - loss: 0.0915 - accuracy: 0.9651 - val_loss: 0.4984 - val_accuracy: 0.8308
# Epoch 49/50
# 55/55 [==============================] - 8s 143ms/step - loss: 0.0915 - accuracy: 0.9653 - val_loss: 0.5045 - val_accuracy: 0.8283
# Epoch 50/50
# 55/55 [==============================] - 8s 144ms/step - loss: 0.0870 - accuracy: 0.9672 - val_loss: 0.4998 - val_accuracy: 0.8276
# Model Fitting done...
# Preparing testing data...
# 100%|██████████| 320/320 [02:00<00:00,  2.66it/s]
# 64/64 [==============================] - 3s 35ms/step
# Calculating metrics...
# Processing images: 100%|██████████| 320/320 [00:35<00:00,  9.07it/s]
# Calculating y_pred: 100%|██████████| 320/320 [00:18<00:00, 16.99it/s]
# Calculating y_test: 100%|██████████| 320/320 [00:17<00:00, 18.11it/s]
#               precision    recall  f1-score   support
#
#          0.0       0.73      0.77      0.75   9903630
#          1.0       0.78      0.74      0.76  11067890
#
#     accuracy                           0.75  20971520
#    macro avg       0.75      0.76      0.75  20971520
# weighted avg       0.76      0.75      0.75  20971520
#
# mIoU: 0.6055621867648355
# 100%|██████████| 320/320 [00:46<00:00,  6.86it/s]
