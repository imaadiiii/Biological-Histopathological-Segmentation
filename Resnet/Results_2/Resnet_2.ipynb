# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, confusion_matrix
from tqdm import tqdm
import tensorflow as tf
from tensorflow import keras
import os
from tensorflow.keras import backend as K
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dropout, UpSampling2D, Input
import cv2
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, confusion_matrix
from tqdm import tqdm
import tensorflow as tf
import os
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dropout, UpSampling2D, Input
from tensorflow.keras import backend as K
from tensorflow.keras.metrics import Accuracy, Precision, Recall
import os

def lab_split(I):
    I = cv2.cvtColor(I, cv2.COLOR_BGR2LAB)
    I = I.astype(np.float32)
    I1, I2, I3 = cv2.split(I)
    I1 /= 2.55
    I2 -= 128.0
    I3 -= 128.0
    return I1, I2, I3

def merge_back(I1, I2, I3):
    I1 *= 2.55
    I2 += 128.0
    I3 += 128.0
    I = np.clip(cv2.merge((I1, I2, I3)), 0, 255).astype(np.uint8)
    return cv2.cvtColor(I, cv2.COLOR_LAB2BGR)

def get_mean_std(I):
    I1, I2, I3 = lab_split(I)
    m1, sd1 = cv2.meanStdDev(I1)
    m2, sd2 = cv2.meanStdDev(I2)
    m3, sd3 = cv2.meanStdDev(I3)
    means = m1, m2, m3
    stds = sd1, sd2, sd3
    return means, stds

def Reinhard_method(target,I):
    means, stds = get_mean_std(target)
    target_means = means
    target_stds = stds
    I1, I2, I3 = lab_split(I)
    means, stds = get_mean_std(I)
    norm1 = ((I1 - means[0]) * (target_stds[0] / stds[0])) + target_means[0]
    norm2 = ((I2 - means[1]) * (target_stds[1] / stds[1])) + target_means[1]
    norm3 = ((I3 - means[2]) * (target_stds[2] / stds[2])) + target_means[2]
    return merge_back(norm1, norm2, norm3)

def calculateClass(img,n_labels,h,w):
    lab=np.zeros([h,w])
    for i in range (h):
        for j in range (w):
            b=img[i][j][0]
            g=img[i][j][1]
            r=img[i][j][2]
            if b==229 and g==155 and r==3:
                lab[i][j]=0
            else:
                lab[i][j]=1
    return lab

def create_label(img, dims,h,w,n_labels=2):
    labels=calculateClass(img,n_labels,h,w)
    x1 = np.zeros([dims[0], dims[1], n_labels])
    for i in range(dims[0]):
        for j in range(dims[1]):
            v1=int(labels[i][j])
            x1[i][j][v1]=1
    x1 = x1.reshape(dims[0] , dims[1], n_labels)
    return x1

def Calculate_metrics(test_image, gt, h, w):
    size = len(test_image)
    h, w, _ = np.shape(test_image[0])
    y_pred = np.zeros((h * w * size, 1))
    y_test = np.zeros((h * w * size, 1))

    res_img = []

    for q in tqdm(range(size), desc="Processing images"):
        img11 = test_image[q]
        img = np.zeros((h, w, 3))
        for i in range(h):
            for j in range(w):
                c1 = img11[i][j][0]
                c2 = img11[i][j][1]
                if c1 > c2:
                    img[i][j] = [0, 0, 0]
                else:
                    img[i][j] = [255, 255, 255]
        res_img.append(img)

    res_img = np.array(res_img)
    c = 0

    for i in tqdm(range(size), desc="Calculating y_pred"):
        img = res_img[i]
        for j in range(h):
            for l in range(w):
                b = img[j][l][0]
                if b == 0:
                    y_pred[c][0] = 0
                else:
                    y_pred[c][0] = 1
                c += 1

    c = 0

    for i in tqdm(range(size), desc="Calculating y_test"):
        img = gt[i]
        for j in range(h):
            for l in range(w):
                b = img[j][l][0]
                if b == 0:
                    y_test[c][0] = 0
                else:
                    y_test[c][0] = 1
                c += 1

    print(classification_report(y_test, y_pred))

    conf_mat = confusion_matrix(y_test, y_pred, labels=[0, 1])
    tp = np.diag(conf_mat)
    fp = np.sum(conf_mat, axis=0) - tp
    fn = np.sum(conf_mat, axis=1) - tp
    iou = tp / (tp + fp + fn + 1e-10)
    miou = np.mean(iou)

    print('mIoU:', miou)
    return

def dice_coef(y_true, y_pred):
    numerator = 2 * K.sum(y_true * y_pred, axis=(1, 2, 3))
    denominator = K.sum(y_true, axis=(1, 2, 3)) + K.sum(y_pred, axis=(1, 2, 3))
    dice_loss = 1 - (numerator + 1) / (denominator + 1)
    return dice_loss

def dice_coef_loss(y_true, y_pred):
    return 1.0 - dice_coef(y_true, y_pred)

def Prepare_data(path_train, path_gt, h, w, n_labels=2):
    target = cv2.imread("/content/drive/MyDrive/Colab_Notebooks/BHI_dataset/Target.png")
    imgs = []
    labels = []

    files_train = os.listdir(path_train)
    files_gt = os.listdir(path_gt)

    base_files_train = set([os.path.splitext(file)[0] for file in files_train])
    base_files_gt = set([os.path.splitext(file)[0] for file in files_gt])

    matching_files = list(set(base_files_train).intersection(base_files_gt))

    for file_base in tqdm(matching_files):
        original_img = cv2.imread(os.path.join(path_train, file_base + ".png"))
        mask = cv2.imread(os.path.join(path_gt, file_base + ".png"))

        resized_img = cv2.resize(original_img, (h, w))
        cn_img = Reinhard_method(target, resized_img)
        array_img = img_to_array(cn_img) / 255
        imgs.append(array_img)

        mask = cv2.resize(mask, (h, w))
        array_mask = create_label(mask, (h, w),h,w,2)
        labels.append(array_mask)
    imgs = np.array(imgs)
    labels = np.array(labels)
    return imgs, labels, matching_files

# RESNET
def bn_act(x, act=True):
    x = keras.layers.BatchNormalization()(x)
    if act == True:
        x = keras.layers.Activation("relu")(x)
    return x

def conv_block(x, filters, kernel_size=(3, 3), padding="same", strides=1):
    conv = bn_act(x)
    conv = keras.layers.Conv2D(filters, kernel_size, padding=padding, strides=strides)(conv)
    return conv

def stem(x, filters, kernel_size=(3, 3), padding="same", strides=1):
    conv = keras.layers.Conv2D(filters, kernel_size, padding=padding, strides=strides)(x)
    conv = conv_block(conv, filters, kernel_size=kernel_size, padding=padding, strides=strides)

    shortcut = keras.layers.Conv2D(filters, kernel_size=(1, 1), padding=padding, strides=strides)(x)
    shortcut = bn_act(shortcut, act=False)

    output = keras.layers.Add()([conv, shortcut])
    return output

def residual_block(x, filters, kernel_size=(3, 3), padding="same", strides=1):
    res = conv_block(x, filters, kernel_size=kernel_size, padding=padding, strides=strides)
    res = conv_block(res, filters, kernel_size=kernel_size, padding=padding, strides=1)

    shortcut = keras.layers.Conv2D(filters, kernel_size=(1, 1), padding=padding, strides=strides)(x)
    shortcut = bn_act(shortcut, act=False)

    output = keras.layers.Add()([shortcut, res])
    return output

def upsample_concat_block(x, xskip):
    u = keras.layers.UpSampling2D((2, 2))(x)
    c = keras.layers.Concatenate()([u, xskip])
    return c

def ResUNet(image_size,lr):
    f = [16, 32, 64, 128, 256]
    inputs = keras.layers.Input((image_size, image_size, 3))

    ## Encoder
    e0 = inputs
    e1 = stem(e0, f[0])
    e2 = residual_block(e1, f[1], strides=2)
    e3 = residual_block(e2, f[2], strides=2)
    e4 = residual_block(e3, f[3], strides=2)
    e5 = residual_block(e4, f[4], strides=2)

    ## Bridge
    b0 = conv_block(e5, f[4], strides=1)
    b1 = conv_block(b0, f[4], strides=1)

    ## Decoder
    u1 = upsample_concat_block(b1, e4)
    d1 = residual_block(u1, f[4])

    u2 = upsample_concat_block(d1, e3)
    d2 = residual_block(u2, f[3])

    u3 = upsample_concat_block(d2, e2)
    d3 = residual_block(u3, f[2])

    u4 = upsample_concat_block(d3, e1)
    d4 = residual_block(u4, f[1])

    outputs = keras.layers.Conv2D(2, (1, 1), padding="same", activation="sigmoid")(d4)
    model = keras.models.Model(inputs, outputs)
    adam = keras.optimizers.Adam(learning_rate=lr)
    model.compile(optimizer=adam, loss=dice_coef_loss, metrics=[dice_coef])
    model.summary()
    return model

if __name__ == "__main__":
    path_train='/content/drive/MyDrive/Colab_Notebooks/BHI_dataset/Gt/'
    path_gt='/content/drive/MyDrive/Colab_Notebooks/BHI_dataset/Img/'

    h=256
    w=256
    lr=0.00001

    print("Preparing and loading training data...")
    X,Y,filenames = Prepare_data(path_train,path_gt,h,w)
    print("Done Preparing training data...")

    nb_epoch = 50
    batch = 5
    n_labels = 2
    model=ResUNet(h,lr)

    print('Model Compiled: OK.....')
    print("Opening model...")
    history=model.fit(x=X,y=Y,batch_size=batch, epochs=nb_epoch, verbose=1,validation_split=0.2)
    print("Model Fitting done...")
    model.save_weights('Resnet.hdf5')
    model.load_weights('Resnet.hdf5')

    fig=plt.figure()
    plt.plot(history.history['dice_coef'])
    plt.plot(history.history['val_dice_coef'])
    plt.title('Model accuracy')
    plt.ylabel('dice_coef')
    plt.xlabel('Epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()
    fig.savefig("U-Net_dice_coef.png")
    # Summarize history for loss
    fig=plt.figure()
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('Model loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()
    fig.savefig("U-Net_loss.png")

    path_test_gt='/content/drive/MyDrive/Colab_Notebooks/BHI_dataset/Img-test/'
    path_test='/content/drive/MyDrive/Colab_Notebooks/BHI_dataset/Gt-test/'
    print("Preparing testing data...")
    test_data,gt,filenames = Prepare_data(path_test,path_test_gt,h,w)
    output = model.predict(test_data,batch_size=batch, verbose=1)

    print("Calculating metrics...")
    Calculate_metrics(output,gt,h,w)

    for i in tqdm(range(len(test_data))):
        Write_output_path = "/content/drive/MyDrive/Colab_Notebooks/BHI_dataset/Resnet/Results_2/Img_" + filenames[i] + ".png"
        out = output[i]
        img = test_data[i]
        for j in range(h):
            for p in range(w):
                if out[j][p][0] > out[j][p][1]:
                    img[j][p] = [0, 0, 0]
                else:
                    img[j][p] = [255, 255, 255]

        cv2.imwrite(Write_output_path, img)
# Out:
# Preparing and loading training data...
# 100%|██████████| 340/340 [03:30<00:00,  1.62it/s]
# Done Preparing training data...
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 256, 256, 3)]        0         []
#
#  conv2d (Conv2D)             (None, 256, 256, 16)         448       ['input_1[0][0]']
#
#  batch_normalization (Batch  (None, 256, 256, 16)         64        ['conv2d[0][0]']
#  Normalization)
#
#  activation (Activation)     (None, 256, 256, 16)         0         ['batch_normalization[0][0]']
#
#  conv2d_2 (Conv2D)           (None, 256, 256, 16)         64        ['input_1[0][0]']
#
#  conv2d_1 (Conv2D)           (None, 256, 256, 16)         2320      ['activation[0][0]']
#
#  batch_normalization_1 (Bat  (None, 256, 256, 16)         64        ['conv2d_2[0][0]']
#  chNormalization)
#
#  add (Add)                   (None, 256, 256, 16)         0         ['conv2d_1[0][0]',
#                                                                      'batch_normalization_1[0][0]'
#                                                                     ]
#
#  batch_normalization_2 (Bat  (None, 256, 256, 16)         64        ['add[0][0]']
#  chNormalization)
#
#  activation_1 (Activation)   (None, 256, 256, 16)         0         ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  conv2d_3 (Conv2D)           (None, 128, 128, 32)         4640      ['activation_1[0][0]']
#
#  batch_normalization_3 (Bat  (None, 128, 128, 32)         128       ['conv2d_3[0][0]']
#  chNormalization)
#
#  conv2d_5 (Conv2D)           (None, 128, 128, 32)         544       ['add[0][0]']
#
#  activation_2 (Activation)   (None, 128, 128, 32)         0         ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  batch_normalization_4 (Bat  (None, 128, 128, 32)         128       ['conv2d_5[0][0]']
#  chNormalization)
#
#  conv2d_4 (Conv2D)           (None, 128, 128, 32)         9248      ['activation_2[0][0]']
#
#  add_1 (Add)                 (None, 128, 128, 32)         0         ['batch_normalization_4[0][0]'
#                                                                     , 'conv2d_4[0][0]']
#
#  batch_normalization_5 (Bat  (None, 128, 128, 32)         128       ['add_1[0][0]']
#  chNormalization)
#
#  activation_3 (Activation)   (None, 128, 128, 32)         0         ['batch_normalization_5[0][0]'
#                                                                     ]
#
#  conv2d_6 (Conv2D)           (None, 64, 64, 64)           18496     ['activation_3[0][0]']
#
#  batch_normalization_6 (Bat  (None, 64, 64, 64)           256       ['conv2d_6[0][0]']
#  chNormalization)
#
#  conv2d_8 (Conv2D)           (None, 64, 64, 64)           2112      ['add_1[0][0]']
#
#  activation_4 (Activation)   (None, 64, 64, 64)           0         ['batch_normalization_6[0][0]'
#                                                                     ]
#
#  batch_normalization_7 (Bat  (None, 64, 64, 64)           256       ['conv2d_8[0][0]']
#  chNormalization)
#
#  conv2d_7 (Conv2D)           (None, 64, 64, 64)           36928     ['activation_4[0][0]']
#
#  add_2 (Add)                 (None, 64, 64, 64)           0         ['batch_normalization_7[0][0]'
#                                                                     , 'conv2d_7[0][0]']
#
#  batch_normalization_8 (Bat  (None, 64, 64, 64)           256       ['add_2[0][0]']
#  chNormalization)
#
#  activation_5 (Activation)   (None, 64, 64, 64)           0         ['batch_normalization_8[0][0]'
#                                                                     ]
#
#  conv2d_9 (Conv2D)           (None, 32, 32, 128)          73856     ['activation_5[0][0]']
#
#  batch_normalization_9 (Bat  (None, 32, 32, 128)          512       ['conv2d_9[0][0]']
#  chNormalization)
#
#  conv2d_11 (Conv2D)          (None, 32, 32, 128)          8320      ['add_2[0][0]']
#
#  activation_6 (Activation)   (None, 32, 32, 128)          0         ['batch_normalization_9[0][0]'
#                                                                     ]
#
#  batch_normalization_10 (Ba  (None, 32, 32, 128)          512       ['conv2d_11[0][0]']
#  tchNormalization)
#
#  conv2d_10 (Conv2D)          (None, 32, 32, 128)          147584    ['activation_6[0][0]']
#
#  add_3 (Add)                 (None, 32, 32, 128)          0         ['batch_normalization_10[0][0]
#                                                                     ',
#                                                                      'conv2d_10[0][0]']
#
#  batch_normalization_11 (Ba  (None, 32, 32, 128)          512       ['add_3[0][0]']
#  tchNormalization)
#
#  activation_7 (Activation)   (None, 32, 32, 128)          0         ['batch_normalization_11[0][0]
#                                                                     ']
#
#  conv2d_12 (Conv2D)          (None, 16, 16, 256)          295168    ['activation_7[0][0]']
#
#  batch_normalization_12 (Ba  (None, 16, 16, 256)          1024      ['conv2d_12[0][0]']
#  tchNormalization)
#
#  conv2d_14 (Conv2D)          (None, 16, 16, 256)          33024     ['add_3[0][0]']
#
#  activation_8 (Activation)   (None, 16, 16, 256)          0         ['batch_normalization_12[0][0]
#                                                                     ']
#
#  batch_normalization_13 (Ba  (None, 16, 16, 256)          1024      ['conv2d_14[0][0]']
#  tchNormalization)
#
#  conv2d_13 (Conv2D)          (None, 16, 16, 256)          590080    ['activation_8[0][0]']
#
#  add_4 (Add)                 (None, 16, 16, 256)          0         ['batch_normalization_13[0][0]
#                                                                     ',
#                                                                      'conv2d_13[0][0]']
#
#  batch_normalization_14 (Ba  (None, 16, 16, 256)          1024      ['add_4[0][0]']
#  tchNormalization)
#
#  activation_9 (Activation)   (None, 16, 16, 256)          0         ['batch_normalization_14[0][0]
#                                                                     ']
#
#  conv2d_15 (Conv2D)          (None, 16, 16, 256)          590080    ['activation_9[0][0]']
#
#  batch_normalization_15 (Ba  (None, 16, 16, 256)          1024      ['conv2d_15[0][0]']
#  tchNormalization)
#
#  activation_10 (Activation)  (None, 16, 16, 256)          0         ['batch_normalization_15[0][0]
#                                                                     ']
#
#  conv2d_16 (Conv2D)          (None, 16, 16, 256)          590080    ['activation_10[0][0]']
#
#  up_sampling2d (UpSampling2  (None, 32, 32, 256)          0         ['conv2d_16[0][0]']
#  D)
#
#  concatenate (Concatenate)   (None, 32, 32, 384)          0         ['up_sampling2d[0][0]',
#                                                                      'add_3[0][0]']
#
#  batch_normalization_16 (Ba  (None, 32, 32, 384)          1536      ['concatenate[0][0]']
#  tchNormalization)
#
#  activation_11 (Activation)  (None, 32, 32, 384)          0         ['batch_normalization_16[0][0]
#                                                                     ']
#
#  conv2d_17 (Conv2D)          (None, 32, 32, 256)          884992    ['activation_11[0][0]']
#
#  batch_normalization_17 (Ba  (None, 32, 32, 256)          1024      ['conv2d_17[0][0]']
#  tchNormalization)
#
#  conv2d_19 (Conv2D)          (None, 32, 32, 256)          98560     ['concatenate[0][0]']
#
#  activation_12 (Activation)  (None, 32, 32, 256)          0         ['batch_normalization_17[0][0]
#                                                                     ']
#
#  batch_normalization_18 (Ba  (None, 32, 32, 256)          1024      ['conv2d_19[0][0]']
#  tchNormalization)
#
#  conv2d_18 (Conv2D)          (None, 32, 32, 256)          590080    ['activation_12[0][0]']
#
#  add_5 (Add)                 (None, 32, 32, 256)          0         ['batch_normalization_18[0][0]
#                                                                     ',
#                                                                      'conv2d_18[0][0]']
#
#  up_sampling2d_1 (UpSamplin  (None, 64, 64, 256)          0         ['add_5[0][0]']
#  g2D)
#
#  concatenate_1 (Concatenate  (None, 64, 64, 320)          0         ['up_sampling2d_1[0][0]',
#  )                                                                   'add_2[0][0]']
#
#  batch_normalization_19 (Ba  (None, 64, 64, 320)          1280      ['concatenate_1[0][0]']
#  tchNormalization)
#
#  activation_13 (Activation)  (None, 64, 64, 320)          0         ['batch_normalization_19[0][0]
#                                                                     ']
#
#  conv2d_20 (Conv2D)          (None, 64, 64, 128)          368768    ['activation_13[0][0]']
#
#  batch_normalization_20 (Ba  (None, 64, 64, 128)          512       ['conv2d_20[0][0]']
#  tchNormalization)
#
#  conv2d_22 (Conv2D)          (None, 64, 64, 128)          41088     ['concatenate_1[0][0]']
#
#  activation_14 (Activation)  (None, 64, 64, 128)          0         ['batch_normalization_20[0][0]
#                                                                     ']
#
#  batch_normalization_21 (Ba  (None, 64, 64, 128)          512       ['conv2d_22[0][0]']
#  tchNormalization)
#
#  conv2d_21 (Conv2D)          (None, 64, 64, 128)          147584    ['activation_14[0][0]']
#
#  add_6 (Add)                 (None, 64, 64, 128)          0         ['batch_normalization_21[0][0]
#                                                                     ',
#                                                                      'conv2d_21[0][0]']
#
#  up_sampling2d_2 (UpSamplin  (None, 128, 128, 128)        0         ['add_6[0][0]']
#  g2D)
#
#  concatenate_2 (Concatenate  (None, 128, 128, 160)        0         ['up_sampling2d_2[0][0]',
#  )                                                                   'add_1[0][0]']
#
#  batch_normalization_22 (Ba  (None, 128, 128, 160)        640       ['concatenate_2[0][0]']
#  tchNormalization)
#
#  activation_15 (Activation)  (None, 128, 128, 160)        0         ['batch_normalization_22[0][0]
#                                                                     ']
#
#  conv2d_23 (Conv2D)          (None, 128, 128, 64)         92224     ['activation_15[0][0]']
#
#  batch_normalization_23 (Ba  (None, 128, 128, 64)         256       ['conv2d_23[0][0]']
#  tchNormalization)
#
#  conv2d_25 (Conv2D)          (None, 128, 128, 64)         10304     ['concatenate_2[0][0]']
#
#  activation_16 (Activation)  (None, 128, 128, 64)         0         ['batch_normalization_23[0][0]
#                                                                     ']
#
#  batch_normalization_24 (Ba  (None, 128, 128, 64)         256       ['conv2d_25[0][0]']
#  tchNormalization)
#
#  conv2d_24 (Conv2D)          (None, 128, 128, 64)         36928     ['activation_16[0][0]']
#
#  add_7 (Add)                 (None, 128, 128, 64)         0         ['batch_normalization_24[0][0]
#                                                                     ',
#                                                                      'conv2d_24[0][0]']
#
#  up_sampling2d_3 (UpSamplin  (None, 256, 256, 64)         0         ['add_7[0][0]']
#  g2D)
#
#  concatenate_3 (Concatenate  (None, 256, 256, 80)         0         ['up_sampling2d_3[0][0]',
#  )                                                                   'add[0][0]']
#
#  batch_normalization_25 (Ba  (None, 256, 256, 80)         320       ['concatenate_3[0][0]']
#  tchNormalization)
#
#  activation_17 (Activation)  (None, 256, 256, 80)         0         ['batch_normalization_25[0][0]
#                                                                     ']
#
#  conv2d_26 (Conv2D)          (None, 256, 256, 32)         23072     ['activation_17[0][0]']
#
#  batch_normalization_26 (Ba  (None, 256, 256, 32)         128       ['conv2d_26[0][0]']
#  tchNormalization)
#
#  conv2d_28 (Conv2D)          (None, 256, 256, 32)         2592      ['concatenate_3[0][0]']
#
#  activation_18 (Activation)  (None, 256, 256, 32)         0         ['batch_normalization_26[0][0]
#                                                                     ']
#
#  batch_normalization_27 (Ba  (None, 256, 256, 32)         128       ['conv2d_28[0][0]']
#  tchNormalization)
#
#  conv2d_27 (Conv2D)          (None, 256, 256, 32)         9248      ['activation_18[0][0]']
#
#  add_8 (Add)                 (None, 256, 256, 32)         0         ['batch_normalization_27[0][0]
#                                                                     ',
#                                                                      'conv2d_27[0][0]']
#
#  conv2d_29 (Conv2D)          (None, 256, 256, 2)          66        ['add_8[0][0]']
#
# ==================================================================================================
# Total params: 4723090 (18.02 MB)
# Trainable params: 4715794 (17.99 MB)
# Non-trainable params: 7296 (28.50 KB)
# __________________________________________________________________________________________________
# Model Compiled: OK.....
# Opening model...
# Epoch 1/50
# 55/55 [==============================] - 51s 362ms/step - loss: 0.4565 - dice_coef: 0.5435 - val_loss: 0.5120 - val_dice_coef: 0.4880
# Epoch 2/50
# 55/55 [==============================] - 7s 134ms/step - loss: 0.3283 - dice_coef: 0.6717 - val_loss: 0.4267 - val_dice_coef: 0.5733
# Epoch 3/50
# 55/55 [==============================] - 7s 135ms/step - loss: 0.2451 - dice_coef: 0.7549 - val_loss: 0.4097 - val_dice_coef: 0.5903
# Epoch 4/50
# 55/55 [==============================] - 7s 135ms/step - loss: 0.1890 - dice_coef: 0.8110 - val_loss: 0.3960 - val_dice_coef: 0.6040
# Epoch 5/50
# 55/55 [==============================] - 7s 135ms/step - loss: 0.1475 - dice_coef: 0.8525 - val_loss: 0.3345 - val_dice_coef: 0.6655
# Epoch 6/50
# 55/55 [==============================] - 7s 132ms/step - loss: 0.1103 - dice_coef: 0.8897 - val_loss: 0.2467 - val_dice_coef: 0.7533
# Epoch 7/50
# 55/55 [==============================] - 7s 136ms/step - loss: 0.0922 - dice_coef: 0.9078 - val_loss: 0.1774 - val_dice_coef: 0.8226
# Epoch 8/50
# 55/55 [==============================] - 7s 135ms/step - loss: 0.0717 - dice_coef: 0.9283 - val_loss: 0.1277 - val_dice_coef: 0.8723
# Epoch 9/50
# 55/55 [==============================] - 8s 137ms/step - loss: 0.0570 - dice_coef: 0.9430 - val_loss: 0.0901 - val_dice_coef: 0.9099
# Epoch 10/50
# 55/55 [==============================] - 7s 135ms/step - loss: 0.0477 - dice_coef: 0.9523 - val_loss: 0.0751 - val_dice_coef: 0.9249
# Epoch 11/50
# 55/55 [==============================] - 7s 136ms/step - loss: 0.0417 - dice_coef: 0.9583 - val_loss: 0.0726 - val_dice_coef: 0.9274
# Epoch 12/50
# 55/55 [==============================] - 7s 135ms/step - loss: 0.0344 - dice_coef: 0.9656 - val_loss: 0.0732 - val_dice_coef: 0.9268
# Epoch 13/50
# 55/55 [==============================] - 8s 138ms/step - loss: 0.0290 - dice_coef: 0.9710 - val_loss: 0.0810 - val_dice_coef: 0.9190
# Epoch 14/50
# 55/55 [==============================] - 7s 133ms/step - loss: 0.0238 - dice_coef: 0.9762 - val_loss: 0.0540 - val_dice_coef: 0.9460
# Epoch 15/50
# 55/55 [==============================] - 7s 136ms/step - loss: 0.0205 - dice_coef: 0.9795 - val_loss: 0.0495 - val_dice_coef: 0.9505
# Epoch 16/50
# 55/55 [==============================] - 7s 136ms/step - loss: 0.0158 - dice_coef: 0.9842 - val_loss: 0.0415 - val_dice_coef: 0.9585
# Epoch 17/50
# 55/55 [==============================] - 7s 136ms/step - loss: 0.0158 - dice_coef: 0.9842 - val_loss: 0.0662 - val_dice_coef: 0.9338
# Epoch 18/50
# 55/55 [==============================] - 7s 136ms/step - loss: 0.0119 - dice_coef: 0.9881 - val_loss: 0.0391 - val_dice_coef: 0.9609
# Epoch 19/50
# 55/55 [==============================] - 7s 136ms/step - loss: 0.0129 - dice_coef: 0.9871 - val_loss: 0.0376 - val_dice_coef: 0.9624
# Epoch 20/50
# 55/55 [==============================] - 7s 134ms/step - loss: 0.0098 - dice_coef: 0.9902 - val_loss: 0.0326 - val_dice_coef: 0.9674
# Epoch 21/50
# 55/55 [==============================] - 8s 137ms/step - loss: 0.0073 - dice_coef: 0.9927 - val_loss: 0.0315 - val_dice_coef: 0.9685
# Epoch 22/50
# 55/55 [==============================] - 7s 135ms/step - loss: 0.0072 - dice_coef: 0.9928 - val_loss: 0.0292 - val_dice_coef: 0.9708
# Epoch 23/50
# 55/55 [==============================] - 7s 137ms/step - loss: 0.0077 - dice_coef: 0.9923 - val_loss: 0.0356 - val_dice_coef: 0.9644
# Epoch 24/50
# 55/55 [==============================] - 8s 137ms/step - loss: 0.0056 - dice_coef: 0.9944 - val_loss: 0.0281 - val_dice_coef: 0.9719
# Epoch 25/50
# 55/55 [==============================] - 8s 139ms/step - loss: 0.0050 - dice_coef: 0.9950 - val_loss: 0.0259 - val_dice_coef: 0.9741
# Epoch 26/50
# 55/55 [==============================] - 8s 138ms/step - loss: 0.0055 - dice_coef: 0.9945 - val_loss: 0.0252 - val_dice_coef: 0.9748
# Epoch 27/50
# 55/55 [==============================] - 8s 139ms/step - loss: 0.0045 - dice_coef: 0.9955 - val_loss: 0.0288 - val_dice_coef: 0.9712
# Epoch 28/50
# 55/55 [==============================] - 8s 137ms/step - loss: 0.0067 - dice_coef: 0.9933 - val_loss: 0.0409 - val_dice_coef: 0.9591
# Epoch 29/50
# 55/55 [==============================] - 8s 139ms/step - loss: 0.0039 - dice_coef: 0.9961 - val_loss: 0.0280 - val_dice_coef: 0.9720
# Epoch 30/50
# 55/55 [==============================] - 8s 137ms/step - loss: 0.0047 - dice_coef: 0.9953 - val_loss: 0.0266 - val_dice_coef: 0.9734
# Epoch 31/50
# 55/55 [==============================] - 7s 136ms/step - loss: 0.0031 - dice_coef: 0.9969 - val_loss: 0.0247 - val_dice_coef: 0.9753
# Epoch 32/50
# 55/55 [==============================] - 8s 139ms/step - loss: 0.0034 - dice_coef: 0.9966 - val_loss: 0.0223 - val_dice_coef: 0.9777
# Epoch 33/50
# 55/55 [==============================] - 8s 139ms/step - loss: 0.0029 - dice_coef: 0.9971 - val_loss: 0.0223 - val_dice_coef: 0.9777
# Epoch 34/50
# 55/55 [==============================] - 8s 138ms/step - loss: 0.0026 - dice_coef: 0.9974 - val_loss: 0.0224 - val_dice_coef: 0.9776
# Epoch 35/50
# 55/55 [==============================] - 8s 139ms/step - loss: 0.0029 - dice_coef: 0.9971 - val_loss: 0.0219 - val_dice_coef: 0.9781
# Epoch 36/50
# 55/55 [==============================] - 8s 141ms/step - loss: 0.0023 - dice_coef: 0.9977 - val_loss: 0.0220 - val_dice_coef: 0.9780
# Epoch 37/50
# 55/55 [==============================] - 8s 138ms/step - loss: 0.0020 - dice_coef: 0.9980 - val_loss: 0.0221 - val_dice_coef: 0.9779
# Epoch 38/50
# 55/55 [==============================] - 8s 138ms/step - loss: 0.0029 - dice_coef: 0.9971 - val_loss: 0.0283 - val_dice_coef: 0.9717
# Epoch 39/50
# 55/55 [==============================] - 7s 136ms/step - loss: 0.0022 - dice_coef: 0.9978 - val_loss: 0.0225 - val_dice_coef: 0.9775
# Epoch 40/50
# 55/55 [==============================] - 8s 140ms/step - loss: 0.0020 - dice_coef: 0.9980 - val_loss: 0.0214 - val_dice_coef: 0.9786
# Epoch 41/50
# 55/55 [==============================] - 8s 138ms/step - loss: 0.0020 - dice_coef: 0.9980 - val_loss: 0.0243 - val_dice_coef: 0.9757
# Epoch 42/50
# 55/55 [==============================] - 8s 141ms/step - loss: 0.0032 - dice_coef: 0.9968 - val_loss: 0.0226 - val_dice_coef: 0.9774
# Epoch 43/50
# 55/55 [==============================] - 7s 136ms/step - loss: 0.0015 - dice_coef: 0.9985 - val_loss: 0.0199 - val_dice_coef: 0.9801
# Epoch 44/50
# 55/55 [==============================] - 8s 140ms/step - loss: 0.0018 - dice_coef: 0.9982 - val_loss: 0.0181 - val_dice_coef: 0.9819
# Epoch 45/50
# 55/55 [==============================] - 8s 137ms/step - loss: 0.0015 - dice_coef: 0.9985 - val_loss: 0.0368 - val_dice_coef: 0.9632
# Epoch 46/50
# 55/55 [==============================] - 8s 141ms/step - loss: 0.0026 - dice_coef: 0.9974 - val_loss: 0.0285 - val_dice_coef: 0.9715
# Epoch 47/50
# 55/55 [==============================] - 8s 137ms/step - loss: 0.0013 - dice_coef: 0.9987 - val_loss: 0.0201 - val_dice_coef: 0.9799
# Epoch 48/50
# 55/55 [==============================] - 8s 140ms/step - loss: 0.0013 - dice_coef: 0.9987 - val_loss: 0.0185 - val_dice_coef: 0.9815
# Epoch 49/50
# 55/55 [==============================] - 8s 140ms/step - loss: 0.0014 - dice_coef: 0.9986 - val_loss: 0.0189 - val_dice_coef: 0.9811
# Epoch 50/50
# 55/55 [==============================] - 8s 140ms/step - loss: 0.0013 - dice_coef: 0.9987 - val_loss: 0.0163 - val_dice_coef: 0.9837
# Model Fitting done...
# Preparing testing data...
# 100%|██████████| 320/320 [03:19<00:00,  1.60it/s]
# 64/64 [==============================] - 3s 35ms/step
# Calculating metrics...
# Processing images: 100%|██████████| 320/320 [00:35<00:00,  9.14it/s]
# Calculating y_pred: 100%|██████████| 320/320 [00:18<00:00, 17.23it/s]
# Calculating y_test: 100%|██████████| 320/320 [00:17<00:00, 18.81it/s]
#               precision    recall  f1-score   support
#
#          0.0       0.77      0.80      0.78  11067890
#          1.0       0.77      0.73      0.75   9903630
#
#     accuracy                           0.77  20971520
#    macro avg       0.77      0.77      0.77  20971520
# weighted avg       0.77      0.77      0.77  20971520
#
# mIoU: 0.620530158403348
# 100%|██████████| 320/320 [00:40<00:00,  7.85it/s]
