# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, confusion_matrix
from tqdm import tqdm
import tensorflow as tf
from tensorflow import keras
import os
from tensorflow.keras import backend as K
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dropout, UpSampling2D, Input
import cv2
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, confusion_matrix
from tqdm import tqdm
import tensorflow as tf
import os
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dropout, UpSampling2D, Input
from tensorflow.keras import backend as K
from tensorflow.keras.metrics import Accuracy, Precision, Recall
import os

def lab_split(I):
    I = cv2.cvtColor(I, cv2.COLOR_BGR2LAB)
    I = I.astype(np.float32)
    I1, I2, I3 = cv2.split(I)
    I1 /= 2.55
    I2 -= 128.0
    I3 -= 128.0
    return I1, I2, I3

def merge_back(I1, I2, I3):
    I1 *= 2.55
    I2 += 128.0
    I3 += 128.0
    I = np.clip(cv2.merge((I1, I2, I3)), 0, 255).astype(np.uint8)
    return cv2.cvtColor(I, cv2.COLOR_LAB2BGR)

def get_mean_std(I):
    I1, I2, I3 = lab_split(I)
    m1, sd1 = cv2.meanStdDev(I1)
    m2, sd2 = cv2.meanStdDev(I2)
    m3, sd3 = cv2.meanStdDev(I3)
    means = m1, m2, m3
    stds = sd1, sd2, sd3
    return means, stds

def Reinhard_method(target,I):
    means, stds = get_mean_std(target)
    target_means = means
    target_stds = stds
    I1, I2, I3 = lab_split(I)
    means, stds = get_mean_std(I)
    norm1 = ((I1 - means[0]) * (target_stds[0] / stds[0])) + target_means[0]
    norm2 = ((I2 - means[1]) * (target_stds[1] / stds[1])) + target_means[1]
    norm3 = ((I3 - means[2]) * (target_stds[2] / stds[2])) + target_means[2]
    return merge_back(norm1, norm2, norm3)

def calculateClass(img,n_labels,h,w):
    lab=np.zeros([h,w])
    for i in range (h):
        for j in range (w):
            b=img[i][j][0]
            g=img[i][j][1]
            r=img[i][j][2]
            if b==229 and g==155 and r==3:
                lab[i][j]=0
            else:
                lab[i][j]=1
    return lab

def create_label(img, dims,h,w,n_labels=2):
    labels=calculateClass(img,n_labels,h,w)
    x1 = np.zeros([dims[0], dims[1], n_labels])
    for i in range(dims[0]):
        for j in range(dims[1]):
            v1=int(labels[i][j])
            x1[i][j][v1]=1
    x1 = x1.reshape(dims[0] , dims[1], n_labels)
    return x1

def Calculate_metrics(test_image, gt, h, w):
    size = len(test_image)
    h, w, _ = np.shape(test_image[0])
    y_pred = np.zeros((h * w * size, 1))
    y_test = np.zeros((h * w * size, 1))

    res_img = []

    for q in tqdm(range(size), desc="Processing images"):
        img11 = test_image[q]
        img = np.zeros((h, w, 3))
        for i in range(h):
            for j in range(w):
                c1 = img11[i][j][0]
                c2 = img11[i][j][1]
                if c1 > c2:
                    img[i][j] = [0, 0, 0]
                else:
                    img[i][j] = [255, 255, 255]
        res_img.append(img)

    res_img = np.array(res_img)
    c = 0

    for i in tqdm(range(size), desc="Calculating y_pred"):
        img = res_img[i]
        for j in range(h):
            for l in range(w):
                b = img[j][l][0]
                if b == 0:
                    y_pred[c][0] = 0
                else:
                    y_pred[c][0] = 1
                c += 1

    c = 0

    for i in tqdm(range(size), desc="Calculating y_test"):
        img = gt[i]
        for j in range(h):
            for l in range(w):
                b = img[j][l][0]
                if b == 1:
                    y_test[c][0] = 0
                else:
                    y_test[c][0] = 1
                c += 1

    print(classification_report(y_test, y_pred))

    conf_mat = confusion_matrix(y_test, y_pred, labels=[0, 1])
    tp = np.diag(conf_mat)
    fp = np.sum(conf_mat, axis=0) - tp
    fn = np.sum(conf_mat, axis=1) - tp
    iou = tp / (tp + fp + fn + 1e-10)
    miou = np.mean(iou)

    print('mIoU:', miou)
    return

def dice_coef(y_true, y_pred):
    numerator = 2 * K.sum(y_true * y_pred, axis=(1, 2, 3))
    denominator = K.sum(y_true, axis=(1, 2, 3)) + K.sum(y_pred, axis=(1, 2, 3))
    dice_loss = 1 - (numerator + 1) / (denominator + 1)
    return dice_loss

def dice_coef_loss(y_true, y_pred):
    return 1.0 - dice_coef(y_true, y_pred)

def Prepare_data(path_train, path_gt, h, w, n_labels=2):
    target = cv2.imread("/content/drive/MyDrive/Colab_Notebooks/BHI_dataset/Target.png")
    imgs = []
    labels = []

    files_train = os.listdir(path_train)
    files_gt = os.listdir(path_gt)

    base_files_train = set([os.path.splitext(file)[0] for file in files_train])
    base_files_gt = set([os.path.splitext(file)[0] for file in files_gt])

    matching_files = list(set(base_files_train).intersection(base_files_gt))

    for file_base in tqdm(matching_files):
        original_img = cv2.imread(os.path.join(path_train, file_base + ".png"))
        mask = cv2.imread(os.path.join(path_gt, file_base + ".png"))

        resized_img = cv2.resize(original_img, (h, w))
        cn_img = Reinhard_method(target, resized_img)
        array_img = img_to_array(cn_img) / 255
        imgs.append(array_img)

        mask = cv2.resize(mask, (h, w))
        array_mask = create_label(mask, (h, w),h,w,2)
        labels.append(array_mask)
    imgs = np.array(imgs)
    labels = np.array(labels)
    return imgs, labels, matching_files

# RESNET
def bn_act(x, act=True):
    x = keras.layers.BatchNormalization()(x)
    if act == True:
        x = keras.layers.Activation("relu")(x)
    return x

def conv_block(x, filters, kernel_size=(3, 3), padding="same", strides=1):
    conv = bn_act(x)
    conv = keras.layers.Conv2D(filters, kernel_size, padding=padding, strides=strides)(conv)
    return conv

def stem(x, filters, kernel_size=(3, 3), padding="same", strides=1):
    conv = keras.layers.Conv2D(filters, kernel_size, padding=padding, strides=strides)(x)
    conv = conv_block(conv, filters, kernel_size=kernel_size, padding=padding, strides=strides)

    shortcut = keras.layers.Conv2D(filters, kernel_size=(1, 1), padding=padding, strides=strides)(x)
    shortcut = bn_act(shortcut, act=False)

    output = keras.layers.Add()([conv, shortcut])
    return output

def residual_block(x, filters, kernel_size=(3, 3), padding="same", strides=1):
    res = conv_block(x, filters, kernel_size=kernel_size, padding=padding, strides=strides)
    res = conv_block(res, filters, kernel_size=kernel_size, padding=padding, strides=1)

    shortcut = keras.layers.Conv2D(filters, kernel_size=(1, 1), padding=padding, strides=strides)(x)
    shortcut = bn_act(shortcut, act=False)

    output = keras.layers.Add()([shortcut, res])
    return output

def upsample_concat_block(x, xskip):
    u = keras.layers.UpSampling2D((2, 2))(x)
    c = keras.layers.Concatenate()([u, xskip])
    return c

def ResUNet(image_size,lr):
    f = [16, 32, 64, 128, 256]
    inputs = keras.layers.Input((image_size, image_size, 3))

    ## Encoder
    e0 = inputs
    e1 = stem(e0, f[0])
    e2 = residual_block(e1, f[1], strides=2)
    e3 = residual_block(e2, f[2], strides=2)
    e4 = residual_block(e3, f[3], strides=2)
    e5 = residual_block(e4, f[4], strides=2)

    ## Bridge
    b0 = conv_block(e5, f[4], strides=1)
    b1 = conv_block(b0, f[4], strides=1)

    ## Decoder
    u1 = upsample_concat_block(b1, e4)
    d1 = residual_block(u1, f[4])

    u2 = upsample_concat_block(d1, e3)
    d2 = residual_block(u2, f[3])

    u3 = upsample_concat_block(d2, e2)
    d3 = residual_block(u3, f[2])

    u4 = upsample_concat_block(d3, e1)
    d4 = residual_block(u4, f[1])

    outputs = keras.layers.Conv2D(2, (1, 1), padding="same", activation="sigmoid")(d4)
    model = keras.models.Model(inputs, outputs)
    adam = keras.optimizers.Adam(learning_rate=lr)
    model.compile(optimizer=adam, loss="binary_crossentropy", metrics=["accuracy"])
    model.summary()
    return model

if __name__ == "__main__":
    path_train='/content/drive/MyDrive/Colab_Notebooks/BHI_dataset/Gt/'
    path_gt='/content/drive/MyDrive/Colab_Notebooks/BHI_dataset/Img/'

    h=256
    w=256
    lr=0.0001

    print("Preparing and loading training data...")
    X,Y,filenames = Prepare_data(path_train,path_gt,h,w)
    print("Done Preparing training data...")

    nb_epoch = 50
    batch = 5
    n_labels = 2
    model=ResUNet(h,lr)

    print('Model Compiled: OK.....')
    print("Opening model...")
    history=model.fit(x=X,y=Y,batch_size=batch, epochs=nb_epoch, verbose=1,validation_split=0.2)
    print("Model Fitting done...")
    model.save_weights('U-Net_50.hdf5')
    model.load_weights('U-Net_50.hdf5')

    fig=plt.figure()
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('Model accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()
    fig.savefig("Resnet-bc.png")
    # Summarize history for loss
    fig=plt.figure()
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('Model loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()
    fig.savefig("U-Net_loss.png")

    path_test_gt='/content/drive/MyDrive/Colab_Notebooks/BHI_dataset/Img-test/'
    path_test='/content/drive/MyDrive/Colab_Notebooks/BHI_dataset/Gt-test/'
    print("Preparing testing data...")
    test_data,gt,filenames = Prepare_data(path_test,path_test_gt,h,w)
    output = model.predict(test_data,batch_size=batch, verbose=1)

    print("Calculating metrics...")
    Calculate_metrics(output,gt,h,w)

    for i in tqdm(range(len(test_data))):
        Write_output_path = "/content/drive/MyDrive/Colab_Notebooks/BHI_dataset/Resnet/Results/Img_" + filenames[i] + ".png"
        out = output[i]
        img = test_data[i]
        for j in range(h):
            for p in range(w):
                if out[j][p][0] > out[j][p][1]:
                    img[j][p] = [0, 0, 0]
                else:
                    img[j][p] = [255, 255, 255]

        cv2.imwrite(Write_output_path, img)
# Out:
# Preparing and loading training data...
# 100%|██████████| 340/340 [02:07<00:00,  2.67it/s]
# Done Preparing training data...
# Model: "model_5"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_6 (InputLayer)        [(None, 256, 256, 3)]        0         []
#
#  conv2d_150 (Conv2D)         (None, 256, 256, 16)         448       ['input_6[0][0]']
#
#  batch_normalization_140 (B  (None, 256, 256, 16)         64        ['conv2d_150[0][0]']
#  atchNormalization)
#
#  activation_95 (Activation)  (None, 256, 256, 16)         0         ['batch_normalization_140[0][0
#                                                                     ]']
#
#  conv2d_152 (Conv2D)         (None, 256, 256, 16)         64        ['input_6[0][0]']
#
#  conv2d_151 (Conv2D)         (None, 256, 256, 16)         2320      ['activation_95[0][0]']
#
#  batch_normalization_141 (B  (None, 256, 256, 16)         64        ['conv2d_152[0][0]']
#  atchNormalization)
#
#  add_45 (Add)                (None, 256, 256, 16)         0         ['conv2d_151[0][0]',
#                                                                      'batch_normalization_141[0][0
#                                                                     ]']
#
#  batch_normalization_142 (B  (None, 256, 256, 16)         64        ['add_45[0][0]']
#  atchNormalization)
#
#  activation_96 (Activation)  (None, 256, 256, 16)         0         ['batch_normalization_142[0][0
#                                                                     ]']
#
#  conv2d_153 (Conv2D)         (None, 128, 128, 32)         4640      ['activation_96[0][0]']
#
#  batch_normalization_143 (B  (None, 128, 128, 32)         128       ['conv2d_153[0][0]']
#  atchNormalization)
#
#  conv2d_155 (Conv2D)         (None, 128, 128, 32)         544       ['add_45[0][0]']
#
#  activation_97 (Activation)  (None, 128, 128, 32)         0         ['batch_normalization_143[0][0
#                                                                     ]']
#
#  batch_normalization_144 (B  (None, 128, 128, 32)         128       ['conv2d_155[0][0]']
#  atchNormalization)
#
#  conv2d_154 (Conv2D)         (None, 128, 128, 32)         9248      ['activation_97[0][0]']
#
#  add_46 (Add)                (None, 128, 128, 32)         0         ['batch_normalization_144[0][0
#                                                                     ]',
#                                                                      'conv2d_154[0][0]']
#
#  batch_normalization_145 (B  (None, 128, 128, 32)         128       ['add_46[0][0]']
#  atchNormalization)
#
#  activation_98 (Activation)  (None, 128, 128, 32)         0         ['batch_normalization_145[0][0
#                                                                     ]']
#
#  conv2d_156 (Conv2D)         (None, 64, 64, 64)           18496     ['activation_98[0][0]']
#
#  batch_normalization_146 (B  (None, 64, 64, 64)           256       ['conv2d_156[0][0]']
#  atchNormalization)
#
#  conv2d_158 (Conv2D)         (None, 64, 64, 64)           2112      ['add_46[0][0]']
#
#  activation_99 (Activation)  (None, 64, 64, 64)           0         ['batch_normalization_146[0][0
#                                                                     ]']
#
#  batch_normalization_147 (B  (None, 64, 64, 64)           256       ['conv2d_158[0][0]']
#  atchNormalization)
#
#  conv2d_157 (Conv2D)         (None, 64, 64, 64)           36928     ['activation_99[0][0]']
#
#  add_47 (Add)                (None, 64, 64, 64)           0         ['batch_normalization_147[0][0
#                                                                     ]',
#                                                                      'conv2d_157[0][0]']
#
#  batch_normalization_148 (B  (None, 64, 64, 64)           256       ['add_47[0][0]']
#  atchNormalization)
#
#  activation_100 (Activation  (None, 64, 64, 64)           0         ['batch_normalization_148[0][0
#  )                                                                  ]']
#
#  conv2d_159 (Conv2D)         (None, 32, 32, 128)          73856     ['activation_100[0][0]']
#
#  batch_normalization_149 (B  (None, 32, 32, 128)          512       ['conv2d_159[0][0]']
#  atchNormalization)
#
#  conv2d_161 (Conv2D)         (None, 32, 32, 128)          8320      ['add_47[0][0]']
#
#  activation_101 (Activation  (None, 32, 32, 128)          0         ['batch_normalization_149[0][0
#  )                                                                  ]']
#
#  batch_normalization_150 (B  (None, 32, 32, 128)          512       ['conv2d_161[0][0]']
#  atchNormalization)
#
#  conv2d_160 (Conv2D)         (None, 32, 32, 128)          147584    ['activation_101[0][0]']
#
#  add_48 (Add)                (None, 32, 32, 128)          0         ['batch_normalization_150[0][0
#                                                                     ]',
#                                                                      'conv2d_160[0][0]']
#
#  batch_normalization_151 (B  (None, 32, 32, 128)          512       ['add_48[0][0]']
#  atchNormalization)
#
#  activation_102 (Activation  (None, 32, 32, 128)          0         ['batch_normalization_151[0][0
#  )                                                                  ]']
#
#  conv2d_162 (Conv2D)         (None, 16, 16, 256)          295168    ['activation_102[0][0]']
#
#  batch_normalization_152 (B  (None, 16, 16, 256)          1024      ['conv2d_162[0][0]']
#  atchNormalization)
#
#  conv2d_164 (Conv2D)         (None, 16, 16, 256)          33024     ['add_48[0][0]']
#
#  activation_103 (Activation  (None, 16, 16, 256)          0         ['batch_normalization_152[0][0
#  )                                                                  ]']
#
#  batch_normalization_153 (B  (None, 16, 16, 256)          1024      ['conv2d_164[0][0]']
#  atchNormalization)
#
#  conv2d_163 (Conv2D)         (None, 16, 16, 256)          590080    ['activation_103[0][0]']
#
#  add_49 (Add)                (None, 16, 16, 256)          0         ['batch_normalization_153[0][0
#                                                                     ]',
#                                                                      'conv2d_163[0][0]']
#
#  batch_normalization_154 (B  (None, 16, 16, 256)          1024      ['add_49[0][0]']
#  atchNormalization)
#
#  activation_104 (Activation  (None, 16, 16, 256)          0         ['batch_normalization_154[0][0
#  )                                                                  ]']
#
#  conv2d_165 (Conv2D)         (None, 16, 16, 256)          590080    ['activation_104[0][0]']
#
#  batch_normalization_155 (B  (None, 16, 16, 256)          1024      ['conv2d_165[0][0]']
#  atchNormalization)
#
#  activation_105 (Activation  (None, 16, 16, 256)          0         ['batch_normalization_155[0][0
#  )                                                                  ]']
#
#  conv2d_166 (Conv2D)         (None, 16, 16, 256)          590080    ['activation_105[0][0]']
#
#  up_sampling2d_20 (UpSampli  (None, 32, 32, 256)          0         ['conv2d_166[0][0]']
#  ng2D)
#
#  concatenate_20 (Concatenat  (None, 32, 32, 384)          0         ['up_sampling2d_20[0][0]',
#  e)                                                                  'add_48[0][0]']
#
#  batch_normalization_156 (B  (None, 32, 32, 384)          1536      ['concatenate_20[0][0]']
#  atchNormalization)
#
#  activation_106 (Activation  (None, 32, 32, 384)          0         ['batch_normalization_156[0][0
#  )                                                                  ]']
#
#  conv2d_167 (Conv2D)         (None, 32, 32, 256)          884992    ['activation_106[0][0]']
#
#  batch_normalization_157 (B  (None, 32, 32, 256)          1024      ['conv2d_167[0][0]']
#  atchNormalization)
#
#  conv2d_169 (Conv2D)         (None, 32, 32, 256)          98560     ['concatenate_20[0][0]']
#
#  activation_107 (Activation  (None, 32, 32, 256)          0         ['batch_normalization_157[0][0
#  )                                                                  ]']
#
#  batch_normalization_158 (B  (None, 32, 32, 256)          1024      ['conv2d_169[0][0]']
#  atchNormalization)
#
#  conv2d_168 (Conv2D)         (None, 32, 32, 256)          590080    ['activation_107[0][0]']
#
#  add_50 (Add)                (None, 32, 32, 256)          0         ['batch_normalization_158[0][0
#                                                                     ]',
#                                                                      'conv2d_168[0][0]']
#
#  up_sampling2d_21 (UpSampli  (None, 64, 64, 256)          0         ['add_50[0][0]']
#  ng2D)
#
#  concatenate_21 (Concatenat  (None, 64, 64, 320)          0         ['up_sampling2d_21[0][0]',
#  e)                                                                  'add_47[0][0]']
#
#  batch_normalization_159 (B  (None, 64, 64, 320)          1280      ['concatenate_21[0][0]']
#  atchNormalization)
#
#  activation_108 (Activation  (None, 64, 64, 320)          0         ['batch_normalization_159[0][0
#  )                                                                  ]']
#
#  conv2d_170 (Conv2D)         (None, 64, 64, 128)          368768    ['activation_108[0][0]']
#
#  batch_normalization_160 (B  (None, 64, 64, 128)          512       ['conv2d_170[0][0]']
#  atchNormalization)
#
#  conv2d_172 (Conv2D)         (None, 64, 64, 128)          41088     ['concatenate_21[0][0]']
#
#  activation_109 (Activation  (None, 64, 64, 128)          0         ['batch_normalization_160[0][0
#  )                                                                  ]']
#
#  batch_normalization_161 (B  (None, 64, 64, 128)          512       ['conv2d_172[0][0]']
#  atchNormalization)
#
#  conv2d_171 (Conv2D)         (None, 64, 64, 128)          147584    ['activation_109[0][0]']
#
#  add_51 (Add)                (None, 64, 64, 128)          0         ['batch_normalization_161[0][0
#                                                                     ]',
#                                                                      'conv2d_171[0][0]']
#
#  up_sampling2d_22 (UpSampli  (None, 128, 128, 128)        0         ['add_51[0][0]']
#  ng2D)
#
#  concatenate_22 (Concatenat  (None, 128, 128, 160)        0         ['up_sampling2d_22[0][0]',
#  e)                                                                  'add_46[0][0]']
#
#  batch_normalization_162 (B  (None, 128, 128, 160)        640       ['concatenate_22[0][0]']
#  atchNormalization)
#
#  activation_110 (Activation  (None, 128, 128, 160)        0         ['batch_normalization_162[0][0
#  )                                                                  ]']
#
#  conv2d_173 (Conv2D)         (None, 128, 128, 64)         92224     ['activation_110[0][0]']
#
#  batch_normalization_163 (B  (None, 128, 128, 64)         256       ['conv2d_173[0][0]']
#  atchNormalization)
#
#  conv2d_175 (Conv2D)         (None, 128, 128, 64)         10304     ['concatenate_22[0][0]']
#
#  activation_111 (Activation  (None, 128, 128, 64)         0         ['batch_normalization_163[0][0
#  )                                                                  ]']
#
#  batch_normalization_164 (B  (None, 128, 128, 64)         256       ['conv2d_175[0][0]']
#  atchNormalization)
#
#  conv2d_174 (Conv2D)         (None, 128, 128, 64)         36928     ['activation_111[0][0]']
#
#  add_52 (Add)                (None, 128, 128, 64)         0         ['batch_normalization_164[0][0
#                                                                     ]',
#                                                                      'conv2d_174[0][0]']
#
#  up_sampling2d_23 (UpSampli  (None, 256, 256, 64)         0         ['add_52[0][0]']
#  ng2D)
#
#  concatenate_23 (Concatenat  (None, 256, 256, 80)         0         ['up_sampling2d_23[0][0]',
#  e)                                                                  'add_45[0][0]']
#
#  batch_normalization_165 (B  (None, 256, 256, 80)         320       ['concatenate_23[0][0]']
#  atchNormalization)
#
#  activation_112 (Activation  (None, 256, 256, 80)         0         ['batch_normalization_165[0][0
#  )                                                                  ]']
#
#  conv2d_176 (Conv2D)         (None, 256, 256, 32)         23072     ['activation_112[0][0]']
#
#  batch_normalization_166 (B  (None, 256, 256, 32)         128       ['conv2d_176[0][0]']
#  atchNormalization)
#
#  conv2d_178 (Conv2D)         (None, 256, 256, 32)         2592      ['concatenate_23[0][0]']
#
#  activation_113 (Activation  (None, 256, 256, 32)         0         ['batch_normalization_166[0][0
#  )                                                                  ]']
#
#  batch_normalization_167 (B  (None, 256, 256, 32)         128       ['conv2d_178[0][0]']
#  atchNormalization)
#
#  conv2d_177 (Conv2D)         (None, 256, 256, 32)         9248      ['activation_113[0][0]']
#
#  add_53 (Add)                (None, 256, 256, 32)         0         ['batch_normalization_167[0][0
#                                                                     ]',
#                                                                      'conv2d_177[0][0]']
#
#  conv2d_179 (Conv2D)         (None, 256, 256, 2)          66        ['add_53[0][0]']
#
# ==================================================================================================
# Total params: 4723090 (18.02 MB)
# Trainable params: 4715794 (17.99 MB)
# Non-trainable params: 7296 (28.50 KB)
# __________________________________________________________________________________________________
# Model Compiled: OK.....
# Opening model...
# Epoch 1/50
# 55/55 [==============================] - 26s 150ms/step - loss: 0.6014 - accuracy: 0.7170 - val_loss: 0.6971 - val_accuracy: 0.5187
# Epoch 2/50
# 55/55 [==============================] - 7s 136ms/step - loss: 0.4364 - accuracy: 0.8034 - val_loss: 0.7230 - val_accuracy: 0.5429
# Epoch 3/50
# 55/55 [==============================] - 8s 137ms/step - loss: 0.3439 - accuracy: 0.8540 - val_loss: 0.6904 - val_accuracy: 0.5818
# Epoch 4/50
# 55/55 [==============================] - 7s 135ms/step - loss: 0.2577 - accuracy: 0.8956 - val_loss: 0.6712 - val_accuracy: 0.5989
# Epoch 5/50
# 55/55 [==============================] - 7s 135ms/step - loss: 0.1911 - accuracy: 0.9257 - val_loss: 1.2920 - val_accuracy: 0.5297
# Epoch 6/50
# 55/55 [==============================] - 7s 136ms/step - loss: 0.2030 - accuracy: 0.9196 - val_loss: 0.8762 - val_accuracy: 0.5987
# Epoch 7/50
# 55/55 [==============================] - 7s 136ms/step - loss: 0.1343 - accuracy: 0.9494 - val_loss: 0.5727 - val_accuracy: 0.7408
# Epoch 8/50
# 55/55 [==============================] - 8s 138ms/step - loss: 0.1054 - accuracy: 0.9604 - val_loss: 0.4334 - val_accuracy: 0.8179
# Epoch 9/50
# 55/55 [==============================] - 8s 138ms/step - loss: 0.0956 - accuracy: 0.9633 - val_loss: 0.3846 - val_accuracy: 0.8473
# Epoch 10/50
# 55/55 [==============================] - 8s 139ms/step - loss: 0.0833 - accuracy: 0.9678 - val_loss: 0.3705 - val_accuracy: 0.8592
# Epoch 11/50
# 55/55 [==============================] - 8s 137ms/step - loss: 0.0816 - accuracy: 0.9685 - val_loss: 0.3818 - val_accuracy: 0.8626
# Epoch 12/50
# 55/55 [==============================] - 8s 140ms/step - loss: 0.0946 - accuracy: 0.9634 - val_loss: 0.4529 - val_accuracy: 0.8588
# Epoch 13/50
# 55/55 [==============================] - 8s 138ms/step - loss: 0.0899 - accuracy: 0.9654 - val_loss: 0.4313 - val_accuracy: 0.8573
# Epoch 14/50
# 55/55 [==============================] - 8s 138ms/step - loss: 0.0704 - accuracy: 0.9730 - val_loss: 0.4142 - val_accuracy: 0.8635
# Epoch 15/50
# 55/55 [==============================] - 8s 139ms/step - loss: 0.0637 - accuracy: 0.9753 - val_loss: 0.3957 - val_accuracy: 0.8679
# Epoch 16/50
# 55/55 [==============================] - 8s 140ms/step - loss: 0.0553 - accuracy: 0.9784 - val_loss: 0.3725 - val_accuracy: 0.8734
# Epoch 17/50
# 55/55 [==============================] - 8s 139ms/step - loss: 0.0490 - accuracy: 0.9809 - val_loss: 0.3636 - val_accuracy: 0.8786
# Epoch 18/50
# 55/55 [==============================] - 8s 140ms/step - loss: 0.0508 - accuracy: 0.9800 - val_loss: 0.3875 - val_accuracy: 0.8748
# Epoch 19/50
# 55/55 [==============================] - 8s 141ms/step - loss: 0.0479 - accuracy: 0.9812 - val_loss: 0.4211 - val_accuracy: 0.8715
# Epoch 20/50
# 55/55 [==============================] - 8s 141ms/step - loss: 0.0427 - accuracy: 0.9832 - val_loss: 0.4581 - val_accuracy: 0.8676
# Epoch 21/50
# 55/55 [==============================] - 8s 139ms/step - loss: 0.0385 - accuracy: 0.9845 - val_loss: 0.4127 - val_accuracy: 0.8760
# Epoch 22/50
# 55/55 [==============================] - 8s 144ms/step - loss: 0.0370 - accuracy: 0.9852 - val_loss: 0.4348 - val_accuracy: 0.8741
# Epoch 23/50
# 55/55 [==============================] - 8s 140ms/step - loss: 0.0360 - accuracy: 0.9856 - val_loss: 0.4142 - val_accuracy: 0.8793
# Epoch 24/50
# 55/55 [==============================] - 8s 142ms/step - loss: 0.0352 - accuracy: 0.9859 - val_loss: 0.4255 - val_accuracy: 0.8771
# Epoch 25/50
# 55/55 [==============================] - 8s 142ms/step - loss: 0.0330 - accuracy: 0.9867 - val_loss: 0.4363 - val_accuracy: 0.8743
# Epoch 26/50
# 55/55 [==============================] - 8s 141ms/step - loss: 0.0310 - accuracy: 0.9874 - val_loss: 0.4405 - val_accuracy: 0.8773
# Epoch 27/50
# 55/55 [==============================] - 8s 140ms/step - loss: 0.0299 - accuracy: 0.9881 - val_loss: 0.5499 - val_accuracy: 0.8599
# Epoch 28/50
# 55/55 [==============================] - 8s 144ms/step - loss: 0.0301 - accuracy: 0.9880 - val_loss: 0.5370 - val_accuracy: 0.8654
# Epoch 29/50
# 55/55 [==============================] - 8s 142ms/step - loss: 0.0309 - accuracy: 0.9875 - val_loss: 0.4516 - val_accuracy: 0.8791
# Epoch 30/50
# 55/55 [==============================] - 8s 143ms/step - loss: 0.0284 - accuracy: 0.9885 - val_loss: 0.4686 - val_accuracy: 0.8756
# Epoch 31/50
# 55/55 [==============================] - 8s 140ms/step - loss: 0.0266 - accuracy: 0.9892 - val_loss: 0.4689 - val_accuracy: 0.8775
# Epoch 32/50
# 55/55 [==============================] - 8s 142ms/step - loss: 0.0266 - accuracy: 0.9893 - val_loss: 0.4596 - val_accuracy: 0.8825
# Epoch 33/50
# 55/55 [==============================] - 8s 142ms/step - loss: 0.0273 - accuracy: 0.9889 - val_loss: 0.5380 - val_accuracy: 0.8679
# Epoch 34/50
# 55/55 [==============================] - 8s 143ms/step - loss: 0.0274 - accuracy: 0.9890 - val_loss: 0.4950 - val_accuracy: 0.8705
# Epoch 35/50
# 55/55 [==============================] - 8s 140ms/step - loss: 0.1824 - accuracy: 0.9349 - val_loss: 2.0852 - val_accuracy: 0.7753
# Epoch 36/50
# 55/55 [==============================] - 8s 142ms/step - loss: 0.0984 - accuracy: 0.9620 - val_loss: 0.4423 - val_accuracy: 0.8598
# Epoch 37/50
# 55/55 [==============================] - 8s 141ms/step - loss: 0.0459 - accuracy: 0.9820 - val_loss: 0.3256 - val_accuracy: 0.8838
# Epoch 38/50
# 55/55 [==============================] - 8s 144ms/step - loss: 0.0321 - accuracy: 0.9872 - val_loss: 0.3387 - val_accuracy: 0.8853
# Epoch 39/50
# 55/55 [==============================] - 8s 143ms/step - loss: 0.0264 - accuracy: 0.9894 - val_loss: 0.3630 - val_accuracy: 0.8860
# Epoch 40/50
# 55/55 [==============================] - 8s 143ms/step - loss: 0.0328 - accuracy: 0.9880 - val_loss: 0.3988 - val_accuracy: 0.8871
# Epoch 41/50
# 55/55 [==============================] - 8s 142ms/step - loss: 0.0250 - accuracy: 0.9899 - val_loss: 0.4245 - val_accuracy: 0.8806
# Epoch 42/50
# 55/55 [==============================] - 8s 144ms/step - loss: 0.0228 - accuracy: 0.9907 - val_loss: 0.3938 - val_accuracy: 0.8901
# Epoch 43/50
# 55/55 [==============================] - 8s 142ms/step - loss: 0.0207 - accuracy: 0.9916 - val_loss: 0.4217 - val_accuracy: 0.8869
# Epoch 44/50
# 55/55 [==============================] - 8s 144ms/step - loss: 0.0191 - accuracy: 0.9922 - val_loss: 0.4273 - val_accuracy: 0.8890
# Epoch 45/50
# 55/55 [==============================] - 8s 144ms/step - loss: 0.0186 - accuracy: 0.9924 - val_loss: 0.4459 - val_accuracy: 0.8894
# Epoch 46/50
# 55/55 [==============================] - 8s 142ms/step - loss: 0.0189 - accuracy: 0.9923 - val_loss: 0.4640 - val_accuracy: 0.8872
# Epoch 47/50
# 55/55 [==============================] - 8s 144ms/step - loss: 0.0182 - accuracy: 0.9926 - val_loss: 0.4786 - val_accuracy: 0.8879
# Epoch 48/50
# 55/55 [==============================] - 8s 142ms/step - loss: 0.0180 - accuracy: 0.9926 - val_loss: 0.4992 - val_accuracy: 0.8879
# Epoch 49/50
# 55/55 [==============================] - 8s 142ms/step - loss: 0.0174 - accuracy: 0.9928 - val_loss: 0.5015 - val_accuracy: 0.8841
# Epoch 50/50
# 55/55 [==============================] - 8s 142ms/step - loss: 0.0177 - accuracy: 0.9928 - val_loss: 0.5111 - val_accuracy: 0.8888
# Model Fitting done...
# Preparing testing data...
# 100%|██████████| 320/320 [02:02<00:00,  2.62it/s]
# 64/64 [==============================] - 3s 35ms/step
# Calculating metrics...
# Processing images: 100%|██████████| 320/320 [00:35<00:00,  8.99it/s]
# Calculating y_pred: 100%|██████████| 320/320 [00:18<00:00, 16.86it/s]
# Calculating y_test: 100%|██████████| 320/320 [00:17<00:00, 18.01it/s]
#               precision    recall  f1-score   support
#
#          0.0       0.75      0.85      0.80   9903630
#          1.0       0.84      0.75      0.79  11067890
#
#     accuracy                           0.79  20971520
#    macro avg       0.80      0.80      0.79  20971520
# weighted avg       0.80      0.79      0.79  20971520
#
# mIoU: 0.6591470756431488
# 100%|██████████| 320/320 [00:47<00:00,  6.77it/s]
