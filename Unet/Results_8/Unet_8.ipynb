# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, confusion_matrix
from tqdm import tqdm
import tensorflow as tf
import os
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dropout, UpSampling2D, Input
from tensorflow.keras import backend as K
from tensorflow.keras.metrics import Accuracy, Precision, Recall

def lab_split(I):
    I = cv2.cvtColor(I, cv2.COLOR_BGR2LAB)
    I = I.astype(np.float32)
    I1, I2, I3 = cv2.split(I)
    I1 /= 2.55
    I2 -= 128.0
    I3 -= 128.0
    return I1, I2, I3

def merge_back(I1, I2, I3):
    I1 *= 2.55
    I2 += 128.0
    I3 += 128.0
    I = np.clip(cv2.merge((I1, I2, I3)), 0, 255).astype(np.uint8)
    return cv2.cvtColor(I, cv2.COLOR_LAB2BGR)

def get_mean_std(I):
    I1, I2, I3 = lab_split(I)
    m1, sd1 = cv2.meanStdDev(I1)
    m2, sd2 = cv2.meanStdDev(I2)
    m3, sd3 = cv2.meanStdDev(I3)
    means = m1, m2, m3
    stds = sd1, sd2, sd3
    return means, stds

def Reinhard_method(target,I):
    means, stds = get_mean_std(target)
    target_means = means
    target_stds = stds
    I1, I2, I3 = lab_split(I)
    means, stds = get_mean_std(I)
    norm1 = ((I1 - means[0]) * (target_stds[0] / stds[0])) + target_means[0]
    norm2 = ((I2 - means[1]) * (target_stds[1] / stds[1])) + target_means[1]
    norm3 = ((I3 - means[2]) * (target_stds[2] / stds[2])) + target_means[2]
    return merge_back(norm1, norm2, norm3)

def calculateClass(img,n_labels,h,w):
    lab=np.zeros([h,w])
    for i in range (h):
        for j in range (w):
            b=img[i][j][0]
            g=img[i][j][1]
            r=img[i][j][2]
            if b==229 and g==155 and r==3:
                lab[i][j]=0
            else:
                lab[i][j]=1
    return lab

def create_label(img, dims,h,w,n_labels=2):
    labels=calculateClass(img,n_labels,h,w)
    x1 = np.zeros([dims[0], dims[1], n_labels])
    for i in range(dims[0]):
        for j in range(dims[1]):
            v1=int(labels[i][j])
            x1[i][j][v1]=1
    x1 = x1.reshape(dims[0] , dims[1], n_labels)
    return x1

def Calculate_metrics(test_image, gt, h, w):
    size = len(test_image)
    h, w, _ = np.shape(test_image[0])
    y_pred = np.zeros((h * w * size, 1))
    y_test = np.zeros((h * w * size, 1))

    res_img = []

    for q in tqdm(range(size), desc="Processing images"):
        img11 = test_image[q]
        img = np.zeros((h, w, 3))
        for i in range(h):
            for j in range(w):
                c1 = img11[i][j][0]
                c2 = img11[i][j][1]
                if c1 > c2:
                    img[i][j] = [0, 0, 0]
                else:
                    img[i][j] = [255, 255, 255]
        res_img.append(img)

    res_img = np.array(res_img)
    c = 0

    for i in tqdm(range(size), desc="Calculating y_pred"):
        img = res_img[i]
        for j in range(h):
            for l in range(w):
                b = img[j][l][0]
                if b == 0:
                    y_pred[c][0] = 0
                else:
                    y_pred[c][0] = 1
                c += 1

    c = 0

    for i in tqdm(range(size), desc="Calculating y_test"):
        img = gt[i]
        for j in range(h):
            for l in range(w):
                b = img[j][l][0]
                if b == 1:
                    y_test[c][0] = 0
                else:
                    y_test[c][0] = 1
                c += 1

    print(classification_report(y_test, y_pred))

    conf_mat = confusion_matrix(y_test, y_pred, labels=[0, 1])
    tp = np.diag(conf_mat)
    fp = np.sum(conf_mat, axis=0) - tp
    fn = np.sum(conf_mat, axis=1) - tp
    iou = tp / (tp + fp + fn + 1e-10)
    miou = np.mean(iou)

    print('mIoU:', miou)
    return

def dice_coef(y_true, y_pred):
    numerator = 2 * K.sum(y_true * y_pred, axis=(1, 2, 3))
    denominator = K.sum(y_true, axis=(1, 2, 3)) + K.sum(y_pred, axis=(1, 2, 3))
    dice_loss = 1 - (numerator + 1) / (denominator + 1)
    return dice_loss

def dice_coef_loss(y_true, y_pred):
    return 1.0 - dice_coef(y_true, y_pred)

def Prepare_data(path_train, path_gt, h, w, n_labels=2):
    target = cv2.imread("/content/drive/MyDrive/Colab_Notebooks/BHI_dataset/Target.png")
    imgs = []
    labels = []

    files_train = os.listdir(path_train)
    files_gt = os.listdir(path_gt)

    base_files_train = set([os.path.splitext(file)[0] for file in files_train])
    base_files_gt = set([os.path.splitext(file)[0] for file in files_gt])

    matching_files = list(set(base_files_train).intersection(base_files_gt))

    for file_base in tqdm(matching_files):
        original_img = cv2.imread(os.path.join(path_train, file_base + ".png"))
        mask = cv2.imread(os.path.join(path_gt, file_base + ".png"))

        resized_img = cv2.resize(original_img, (h, w))
        cn_img = Reinhard_method(target, resized_img)
        array_img = img_to_array(cn_img) / 255
        imgs.append(array_img)

        mask = cv2.resize(mask, (h, w))
        array_mask = create_label(mask, (h, w),h,w,2)
        labels.append(array_mask)
    imgs = np.array(imgs)
    labels = np.array(labels)
    return imgs, labels, matching_files

def Unet(input_size = (128,128,3)):

    inputs = tf.keras.Input(input_size)
    conv1 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(inputs)
    conv1=tf.keras.layers.BatchNormalization()(conv1)
    conv1 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv1)
    conv1=tf.keras.layers.BatchNormalization()(conv1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)

    conv2 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool1)
    conv2=tf.keras.layers.BatchNormalization()(conv2)
    conv2 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv2)
    conv2=tf.keras.layers.BatchNormalization()(conv2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)

    conv3 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool2)
    conv3=tf.keras.layers.BatchNormalization()(conv3)
    conv3 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv3)
    conv3=tf.keras.layers.BatchNormalization(name='b1')(conv3)
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)

    conv4 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool3)
    conv4=tf.keras.layers.BatchNormalization()(conv4)
    conv4 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv4)
    conv4=tf.keras.layers.BatchNormalization()(conv4)
    drop4 = Dropout(0.5)(conv4)
    pool4 = MaxPooling2D(pool_size=(2, 2))(drop4)

    conv5 = Conv2D(1024, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool4)
    conv5=tf.keras.layers.BatchNormalization()(conv5)
    conv5 = Conv2D(1024, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv5)
    conv5=tf.keras.layers.BatchNormalization()(conv5)
    drop5 =Dropout(0.5)(conv5)

    up6 = Conv2D(512, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(drop5))
    merge6 = tf.keras.layers.concatenate([conv4,up6],  axis = -1)
    conv6 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge6)
    conv6=tf.keras.layers.BatchNormalization()(conv6)
    conv6 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv6)
    conv6=tf.keras.layers.BatchNormalization()(conv6)

    up7 = Conv2D(256, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(conv6))
    merge7 = tf.keras.layers.concatenate([conv3,up7],axis = -1)
    conv7 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge7)
    conv7=tf.keras.layers.BatchNormalization()(conv7)
    conv7 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv7)
    conv7=tf.keras.layers.BatchNormalization()(conv7)

    up8 = Conv2D(128, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(conv7))
    merge8 = tf.keras.layers.concatenate([conv2,up8],axis = -1)
    conv8 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge8)
    conv8=tf.keras.layers.BatchNormalization()(conv8)
    conv8 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv8)
    conv8=tf.keras.layers.BatchNormalization()(conv8)

    up9 = Conv2D(64, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(conv8))
    merge9 = tf.keras.layers.concatenate([conv1,up9], axis = -1)
    conv9 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge9)
    conv9=tf.keras.layers.BatchNormalization()(conv9)
    conv9 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv9)
    conv9=tf.keras.layers.BatchNormalization()(conv9)

    conv10 = Conv2D(2, 1, activation = 'softmax')(conv9)
    model = Model(inputs = [inputs], outputs = [conv10])
    model.compile(optimizer=Adam(learning_rate=0.00001),loss="binary_crossentropy",metrics=["accuracy"])
    model.summary()
    return model

if __name__ == "__main__":
    path_train='/content/drive/MyDrive/Colab_Notebooks/BHI_dataset/Gt/'
    path_gt='/content/drive/MyDrive/Colab_Notebooks/BHI_dataset/Img/'

    h=256
    w=256

    print("Preparing and loading training data...")
    X,Y,filenames = Prepare_data(path_train,path_gt,h,w)
    print("Done Preparing training data...")

    nb_epoch = 50
    batch = 5
    n_labels = 2
    model=Unet((h,w,3))

    print('Model Compiled: OK.....')
    print("Opening model...")
    history=model.fit(x=X,y=Y,batch_size=batch, epochs=nb_epoch, verbose=1,validation_split=0.2)
    print("Model Fitting done...")
    model.save_weights('U-Net_50.hdf5')
    model.load_weights('U-Net_50.hdf5')

    fig=plt.figure()
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('Model accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()
    fig.savefig("U-Net_accuracy.png")
    # Summarize history for loss
    fig=plt.figure()
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('Model loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()
    fig.savefig("U-Net_loss.png")

    path_test_gt='/content/drive/MyDrive/Colab_Notebooks/BHI_dataset/Img-test/'
    path_test='/content/drive/MyDrive/Colab_Notebooks/BHI_dataset/Gt-test/'
    print("Preparing testing data...")
    test_data,gt,filenames = Prepare_data(path_test,path_test_gt,h,w)
    output = model.predict(test_data,batch_size=batch, verbose=1)

    print("Calculating metrics...")
    Calculate_metrics(output,gt,h,w)

for i in tqdm(range(len(test_data))):
    Write_output_path = "/content/drive/MyDrive/Colab_Notebooks/BHI_dataset/Unet/Results_8/Img_" + filenames[i] + ".png"
    out = output[i]
    img = test_data[i]

    for j in range(h):
        for p in range(w):
            if out[j][p][0] > out[j][p][1]:
                img[j][p] = [0, 0, 0]
            else:
                img[j][p] = [255, 255, 255]
        cv2.imwrite(Write_output_path, img)
# Out:
# Preparing and loading training data...
# 100%|██████████| 340/340 [02:02<00:00,  2.78it/s]
# Done Preparing training data...
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_3 (InputLayer)        [(None, 256, 256, 3)]        0         []
#
#  conv2d_46 (Conv2D)          (None, 256, 256, 64)         1792      ['input_3[0][0]']
#
#  batch_normalization_34 (Ba  (None, 256, 256, 64)         256       ['conv2d_46[0][0]']
#  tchNormalization)
#
#  conv2d_47 (Conv2D)          (None, 256, 256, 64)         36928     ['batch_normalization_34[0][0]
#                                                                     ']
#
#  batch_normalization_35 (Ba  (None, 256, 256, 64)         256       ['conv2d_47[0][0]']
#  tchNormalization)
#
#  max_pooling2d_8 (MaxPoolin  (None, 128, 128, 64)         0         ['batch_normalization_35[0][0]
#  g2D)                                                               ']
#
#  conv2d_48 (Conv2D)          (None, 128, 128, 128)        73856     ['max_pooling2d_8[0][0]']
#
#  batch_normalization_36 (Ba  (None, 128, 128, 128)        512       ['conv2d_48[0][0]']
#  tchNormalization)
#
#  conv2d_49 (Conv2D)          (None, 128, 128, 128)        147584    ['batch_normalization_36[0][0]
#                                                                     ']
#
#  batch_normalization_37 (Ba  (None, 128, 128, 128)        512       ['conv2d_49[0][0]']
#  tchNormalization)
#
#  max_pooling2d_9 (MaxPoolin  (None, 64, 64, 128)          0         ['batch_normalization_37[0][0]
#  g2D)                                                               ']
#
#  conv2d_50 (Conv2D)          (None, 64, 64, 256)          295168    ['max_pooling2d_9[0][0]']
#
#  batch_normalization_38 (Ba  (None, 64, 64, 256)          1024      ['conv2d_50[0][0]']
#  tchNormalization)
#
#  conv2d_51 (Conv2D)          (None, 64, 64, 256)          590080    ['batch_normalization_38[0][0]
#                                                                     ']
#
#  b1 (BatchNormalization)     (None, 64, 64, 256)          1024      ['conv2d_51[0][0]']
#
#  max_pooling2d_10 (MaxPooli  (None, 32, 32, 256)          0         ['b1[0][0]']
#  ng2D)
#
#  conv2d_52 (Conv2D)          (None, 32, 32, 512)          1180160   ['max_pooling2d_10[0][0]']
#
#  batch_normalization_39 (Ba  (None, 32, 32, 512)          2048      ['conv2d_52[0][0]']
#  tchNormalization)
#
#  conv2d_53 (Conv2D)          (None, 32, 32, 512)          2359808   ['batch_normalization_39[0][0]
#                                                                     ']
#
#  batch_normalization_40 (Ba  (None, 32, 32, 512)          2048      ['conv2d_53[0][0]']
#  tchNormalization)
#
#  dropout_4 (Dropout)         (None, 32, 32, 512)          0         ['batch_normalization_40[0][0]
#                                                                     ']
#
#  max_pooling2d_11 (MaxPooli  (None, 16, 16, 512)          0         ['dropout_4[0][0]']
#  ng2D)
#
#  conv2d_54 (Conv2D)          (None, 16, 16, 1024)         4719616   ['max_pooling2d_11[0][0]']
#
#  batch_normalization_41 (Ba  (None, 16, 16, 1024)         4096      ['conv2d_54[0][0]']
#  tchNormalization)
#
#  conv2d_55 (Conv2D)          (None, 16, 16, 1024)         9438208   ['batch_normalization_41[0][0]
#                                                                     ']
#
#  batch_normalization_42 (Ba  (None, 16, 16, 1024)         4096      ['conv2d_55[0][0]']
#  tchNormalization)
#
#  dropout_5 (Dropout)         (None, 16, 16, 1024)         0         ['batch_normalization_42[0][0]
#                                                                     ']
#
#  up_sampling2d_8 (UpSamplin  (None, 32, 32, 1024)         0         ['dropout_5[0][0]']
#  g2D)
#
#  conv2d_56 (Conv2D)          (None, 32, 32, 512)          2097664   ['up_sampling2d_8[0][0]']
#
#  concatenate_8 (Concatenate  (None, 32, 32, 1024)         0         ['batch_normalization_40[0][0]
#  )                                                                  ',
#                                                                      'conv2d_56[0][0]']
#
#  conv2d_57 (Conv2D)          (None, 32, 32, 512)          4719104   ['concatenate_8[0][0]']
#
#  batch_normalization_43 (Ba  (None, 32, 32, 512)          2048      ['conv2d_57[0][0]']
#  tchNormalization)
#
#  conv2d_58 (Conv2D)          (None, 32, 32, 512)          2359808   ['batch_normalization_43[0][0]
#                                                                     ']
#
#  batch_normalization_44 (Ba  (None, 32, 32, 512)          2048      ['conv2d_58[0][0]']
#  tchNormalization)
#
#  up_sampling2d_9 (UpSamplin  (None, 64, 64, 512)          0         ['batch_normalization_44[0][0]
#  g2D)                                                               ']
#
#  conv2d_59 (Conv2D)          (None, 64, 64, 256)          524544    ['up_sampling2d_9[0][0]']
#
#  concatenate_9 (Concatenate  (None, 64, 64, 512)          0         ['b1[0][0]',
#  )                                                                   'conv2d_59[0][0]']
#
#  conv2d_60 (Conv2D)          (None, 64, 64, 256)          1179904   ['concatenate_9[0][0]']
#
#  batch_normalization_45 (Ba  (None, 64, 64, 256)          1024      ['conv2d_60[0][0]']
#  tchNormalization)
#
#  conv2d_61 (Conv2D)          (None, 64, 64, 256)          590080    ['batch_normalization_45[0][0]
#                                                                     ']
#
#  batch_normalization_46 (Ba  (None, 64, 64, 256)          1024      ['conv2d_61[0][0]']
#  tchNormalization)
#
#  up_sampling2d_10 (UpSampli  (None, 128, 128, 256)        0         ['batch_normalization_46[0][0]
#  ng2D)                                                              ']
#
#  conv2d_62 (Conv2D)          (None, 128, 128, 128)        131200    ['up_sampling2d_10[0][0]']
#
#  concatenate_10 (Concatenat  (None, 128, 128, 256)        0         ['batch_normalization_37[0][0]
#  e)                                                                 ',
#                                                                      'conv2d_62[0][0]']
#
#  conv2d_63 (Conv2D)          (None, 128, 128, 128)        295040    ['concatenate_10[0][0]']
#
#  batch_normalization_47 (Ba  (None, 128, 128, 128)        512       ['conv2d_63[0][0]']
#  tchNormalization)
#
#  conv2d_64 (Conv2D)          (None, 128, 128, 128)        147584    ['batch_normalization_47[0][0]
#                                                                     ']
#
#  batch_normalization_48 (Ba  (None, 128, 128, 128)        512       ['conv2d_64[0][0]']
#  tchNormalization)
#
#  up_sampling2d_11 (UpSampli  (None, 256, 256, 128)        0         ['batch_normalization_48[0][0]
#  ng2D)                                                              ']
#
#  conv2d_65 (Conv2D)          (None, 256, 256, 64)         32832     ['up_sampling2d_11[0][0]']
#
#  concatenate_11 (Concatenat  (None, 256, 256, 128)        0         ['batch_normalization_35[0][0]
#  e)                                                                 ',
#                                                                      'conv2d_65[0][0]']
#
#  conv2d_66 (Conv2D)          (None, 256, 256, 64)         73792     ['concatenate_11[0][0]']
#
#  batch_normalization_49 (Ba  (None, 256, 256, 64)         256       ['conv2d_66[0][0]']
#  tchNormalization)
#
#  conv2d_67 (Conv2D)          (None, 256, 256, 64)         36928     ['batch_normalization_49[0][0]
#                                                                     ']
#
#  batch_normalization_50 (Ba  (None, 256, 256, 64)         256       ['conv2d_67[0][0]']
#  tchNormalization)
#
#  conv2d_68 (Conv2D)          (None, 256, 256, 2)          130       ['batch_normalization_50[0][0]
#                                                                     ']
#
# ==================================================================================================
# Total params: 31055362 (118.47 MB)
# Trainable params: 31043586 (118.42 MB)
# Non-trainable params: 11776 (46.00 KB)
# __________________________________________________________________________________________________
# Model Compiled: OK.....
# Opening model...
# Epoch 1/50
# 55/55 [==============================] - 38s 509ms/step - loss: 0.7835 - accuracy: 0.6010 - val_loss: 0.7094 - val_accuracy: 0.5104
# Epoch 2/50
# 55/55 [==============================] - 28s 508ms/step - loss: 0.6401 - accuracy: 0.6942 - val_loss: 0.6874 - val_accuracy: 0.5571
# Epoch 3/50
# 55/55 [==============================] - 28s 501ms/step - loss: 0.5420 - accuracy: 0.7487 - val_loss: 0.6329 - val_accuracy: 0.6428
# Epoch 4/50
# 55/55 [==============================] - 29s 527ms/step - loss: 0.4727 - accuracy: 0.7894 - val_loss: 0.6293 - val_accuracy: 0.6798
# Epoch 5/50
# 55/55 [==============================] - 28s 508ms/step - loss: 0.4213 - accuracy: 0.8149 - val_loss: 0.9163 - val_accuracy: 0.6611
# Epoch 6/50
# 55/55 [==============================] - 29s 524ms/step - loss: 0.3987 - accuracy: 0.8272 - val_loss: 0.8687 - val_accuracy: 0.6866
# Epoch 7/50
# 55/55 [==============================] - 29s 526ms/step - loss: 0.3713 - accuracy: 0.8381 - val_loss: 0.6428 - val_accuracy: 0.7791
# Epoch 8/50
# 55/55 [==============================] - 28s 508ms/step - loss: 0.3324 - accuracy: 0.8601 - val_loss: 0.6651 - val_accuracy: 0.7843
# Epoch 9/50
# 55/55 [==============================] - 28s 508ms/step - loss: 0.3171 - accuracy: 0.8654 - val_loss: 0.5371 - val_accuracy: 0.8177
# Epoch 10/50
# 55/55 [==============================] - 29s 523ms/step - loss: 0.3056 - accuracy: 0.8724 - val_loss: 0.5621 - val_accuracy: 0.8254
# Epoch 11/50
# 55/55 [==============================] - 28s 509ms/step - loss: 0.2786 - accuracy: 0.8840 - val_loss: 0.4917 - val_accuracy: 0.8360
# Epoch 12/50
# 55/55 [==============================] - 28s 508ms/step - loss: 0.2627 - accuracy: 0.8918 - val_loss: 0.4424 - val_accuracy: 0.8362
# Epoch 13/50
# 55/55 [==============================] - 28s 507ms/step - loss: 0.2721 - accuracy: 0.8875 - val_loss: 0.4907 - val_accuracy: 0.8405
# Epoch 14/50
# 55/55 [==============================] - 28s 507ms/step - loss: 0.2431 - accuracy: 0.9011 - val_loss: 0.4590 - val_accuracy: 0.8431
# Epoch 15/50
# 55/55 [==============================] - 29s 523ms/step - loss: 0.2433 - accuracy: 0.9006 - val_loss: 0.3915 - val_accuracy: 0.8525
# Epoch 16/50
# 55/55 [==============================] - 29s 524ms/step - loss: 0.2218 - accuracy: 0.9105 - val_loss: 0.4420 - val_accuracy: 0.8520
# Epoch 17/50
# 55/55 [==============================] - 28s 508ms/step - loss: 0.2229 - accuracy: 0.9105 - val_loss: 0.4367 - val_accuracy: 0.8507
# Epoch 18/50
# 55/55 [==============================] - 29s 525ms/step - loss: 0.2144 - accuracy: 0.9133 - val_loss: 0.4356 - val_accuracy: 0.8612
# Epoch 19/50
# 55/55 [==============================] - 29s 523ms/step - loss: 0.2121 - accuracy: 0.9137 - val_loss: 0.4059 - val_accuracy: 0.8559
# Epoch 20/50
# 55/55 [==============================] - 29s 524ms/step - loss: 0.2129 - accuracy: 0.9144 - val_loss: 0.5169 - val_accuracy: 0.8504
# Epoch 21/50
# 55/55 [==============================] - 29s 524ms/step - loss: 0.1987 - accuracy: 0.9210 - val_loss: 0.4505 - val_accuracy: 0.8603
# Epoch 22/50
# 55/55 [==============================] - 28s 509ms/step - loss: 0.1880 - accuracy: 0.9251 - val_loss: 0.4154 - val_accuracy: 0.8699
# Epoch 23/50
# 55/55 [==============================] - 28s 508ms/step - loss: 0.1856 - accuracy: 0.9264 - val_loss: 0.4349 - val_accuracy: 0.8705
# Epoch 24/50
# 55/55 [==============================] - 28s 508ms/step - loss: 0.1821 - accuracy: 0.9288 - val_loss: 0.3958 - val_accuracy: 0.8684
# Epoch 25/50
# 55/55 [==============================] - 28s 507ms/step - loss: 0.1786 - accuracy: 0.9300 - val_loss: 0.4617 - val_accuracy: 0.8563
# Epoch 26/50
# 55/55 [==============================] - 28s 508ms/step - loss: 0.1689 - accuracy: 0.9338 - val_loss: 0.4516 - val_accuracy: 0.8701
# Epoch 27/50
# 55/55 [==============================] - 29s 523ms/step - loss: 0.1695 - accuracy: 0.9332 - val_loss: 0.4507 - val_accuracy: 0.8632
# Epoch 28/50
# 55/55 [==============================] - 28s 507ms/step - loss: 0.1640 - accuracy: 0.9359 - val_loss: 0.4057 - val_accuracy: 0.8684
# Epoch 29/50
# 55/55 [==============================] - 29s 524ms/step - loss: 0.1728 - accuracy: 0.9322 - val_loss: 0.3853 - val_accuracy: 0.8743
# Epoch 30/50
# 55/55 [==============================] - 28s 508ms/step - loss: 0.1661 - accuracy: 0.9352 - val_loss: 0.4211 - val_accuracy: 0.8686
# Epoch 31/50
# 55/55 [==============================] - 29s 523ms/step - loss: 0.1581 - accuracy: 0.9381 - val_loss: 0.3960 - val_accuracy: 0.8767
# Epoch 32/50
# 55/55 [==============================] - 29s 524ms/step - loss: 0.1458 - accuracy: 0.9435 - val_loss: 0.3925 - val_accuracy: 0.8779
# Epoch 33/50
# 55/55 [==============================] - 29s 527ms/step - loss: 0.1405 - accuracy: 0.9455 - val_loss: 0.4082 - val_accuracy: 0.8775
# Epoch 34/50
# 55/55 [==============================] - 29s 525ms/step - loss: 0.1526 - accuracy: 0.9404 - val_loss: 0.4328 - val_accuracy: 0.8707
# Epoch 35/50
# 55/55 [==============================] - 29s 525ms/step - loss: 0.1504 - accuracy: 0.9419 - val_loss: 0.4337 - val_accuracy: 0.8728
# Epoch 36/50
# 55/55 [==============================] - 28s 510ms/step - loss: 0.1322 - accuracy: 0.9495 - val_loss: 0.3804 - val_accuracy: 0.8804
# Epoch 37/50
# 55/55 [==============================] - 29s 524ms/step - loss: 0.1324 - accuracy: 0.9490 - val_loss: 0.3941 - val_accuracy: 0.8806
# Epoch 38/50
# 55/55 [==============================] - 28s 508ms/step - loss: 0.1359 - accuracy: 0.9475 - val_loss: 0.4333 - val_accuracy: 0.8716
# Epoch 39/50
# 55/55 [==============================] - 28s 507ms/step - loss: 0.1214 - accuracy: 0.9532 - val_loss: 0.3989 - val_accuracy: 0.8790
# Epoch 40/50
# 55/55 [==============================] - 29s 524ms/step - loss: 0.1343 - accuracy: 0.9481 - val_loss: 0.4200 - val_accuracy: 0.8749
# Epoch 41/50
# 55/55 [==============================] - 29s 523ms/step - loss: 0.1252 - accuracy: 0.9518 - val_loss: 0.3990 - val_accuracy: 0.8790
# Epoch 42/50
# 55/55 [==============================] - 29s 523ms/step - loss: 0.1278 - accuracy: 0.9511 - val_loss: 0.4380 - val_accuracy: 0.8789
# Epoch 43/50
# 55/55 [==============================] - 28s 507ms/step - loss: 0.1169 - accuracy: 0.9552 - val_loss: 0.4400 - val_accuracy: 0.8754
# Epoch 44/50
# 55/55 [==============================] - 28s 508ms/step - loss: 0.1217 - accuracy: 0.9534 - val_loss: 0.3943 - val_accuracy: 0.8821
# Epoch 45/50
# 55/55 [==============================] - 29s 524ms/step - loss: 0.1148 - accuracy: 0.9562 - val_loss: 0.4340 - val_accuracy: 0.8781
# Epoch 46/50
# 55/55 [==============================] - 29s 524ms/step - loss: 0.1071 - accuracy: 0.9592 - val_loss: 0.4282 - val_accuracy: 0.8767
# Epoch 47/50
# 55/55 [==============================] - 29s 524ms/step - loss: 0.1147 - accuracy: 0.9563 - val_loss: 0.4132 - val_accuracy: 0.8791
# Epoch 48/50
# 55/55 [==============================] - 29s 525ms/step - loss: 0.1197 - accuracy: 0.9543 - val_loss: 0.3700 - val_accuracy: 0.8834
# Epoch 49/50
# 55/55 [==============================] - 29s 524ms/step - loss: 0.1154 - accuracy: 0.9560 - val_loss: 0.4026 - val_accuracy: 0.8808
# Epoch 50/50
# 55/55 [==============================] - 29s 523ms/step - loss: 0.1126 - accuracy: 0.9572 - val_loss: 0.4254 - val_accuracy: 0.8795
# Model Fitting done...
# Preparing testing data...
# 100%|██████████| 320/320 [01:57<00:00,  2.72it/s]
# 64/64 [==============================] - 8s 117ms/step
# Calculating metrics...
# Processing images: 100%|██████████| 320/320 [00:33<00:00,  9.51it/s]
# Calculating y_pred: 100%|██████████| 320/320 [00:16<00:00, 19.68it/s]
# Calculating y_test: 100%|██████████| 320/320 [00:16<00:00, 19.64it/s]
#               precision    recall  f1-score   support
#
#          0.0       0.83      0.85      0.84   9903630
#          1.0       0.86      0.85      0.86  11067890
#
#     accuracy                           0.85  20971520
#    macro avg       0.85      0.85      0.85  20971520
# weighted avg       0.85      0.85      0.85  20971520
#
# mIoU: 0.7389707635290661
# 100%|██████████| 320/320 [07:24<00:00,  1.39s/it]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
