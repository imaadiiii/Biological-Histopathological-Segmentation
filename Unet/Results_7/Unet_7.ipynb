# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, confusion_matrix
from tqdm import tqdm
import tensorflow as tf
import os
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dropout, UpSampling2D, Input
from tensorflow.keras import backend as K
from tensorflow.keras.metrics import Accuracy, Precision, Recall

def lab_split(I):
    I = cv2.cvtColor(I, cv2.COLOR_BGR2LAB)
    I = I.astype(np.float32)
    I1, I2, I3 = cv2.split(I)
    I1 /= 2.55
    I2 -= 128.0
    I3 -= 128.0
    return I1, I2, I3

def merge_back(I1, I2, I3):
    I1 *= 2.55
    I2 += 128.0
    I3 += 128.0
    I = np.clip(cv2.merge((I1, I2, I3)), 0, 255).astype(np.uint8)
    return cv2.cvtColor(I, cv2.COLOR_LAB2BGR)

def get_mean_std(I):
    I1, I2, I3 = lab_split(I)
    m1, sd1 = cv2.meanStdDev(I1)
    m2, sd2 = cv2.meanStdDev(I2)
    m3, sd3 = cv2.meanStdDev(I3)
    means = m1, m2, m3
    stds = sd1, sd2, sd3
    return means, stds

def Reinhard_method(target,I):
    means, stds = get_mean_std(target)
    target_means = means
    target_stds = stds
    I1, I2, I3 = lab_split(I)
    means, stds = get_mean_std(I)
    norm1 = ((I1 - means[0]) * (target_stds[0] / stds[0])) + target_means[0]
    norm2 = ((I2 - means[1]) * (target_stds[1] / stds[1])) + target_means[1]
    norm3 = ((I3 - means[2]) * (target_stds[2] / stds[2])) + target_means[2]
    return merge_back(norm1, norm2, norm3)

def calculateClass(img,n_labels,h,w):
    lab=np.zeros([h,w])
    for i in range (h):
        for j in range (w):
            b=img[i][j][0]
            g=img[i][j][1]
            r=img[i][j][2]
            if b==229 and g==155 and r==3:
                lab[i][j]=0
            else:
                lab[i][j]=1
    return lab

def create_label(img, dims,h,w,n_labels=2):
    labels=calculateClass(img,n_labels,h,w)
    x1 = np.zeros([dims[0], dims[1], n_labels])
    for i in range(dims[0]):
        for j in range(dims[1]):
            v1=int(labels[i][j])
            x1[i][j][v1]=1
    x1 = x1.reshape(dims[0] , dims[1], n_labels)
    return x1

def Calculate_metrics(test_image, gt, h, w):
    size = len(test_image)
    h, w, _ = np.shape(test_image[0])
    y_pred = np.zeros((h * w * size, 1))
    y_test = np.zeros((h * w * size, 1))

    res_img = []

    for q in tqdm(range(size), desc="Processing images"):
        img11 = test_image[q]
        img = np.zeros((h, w, 3))
        for i in range(h):
            for j in range(w):
                c1 = img11[i][j][0]
                c2 = img11[i][j][1]
                if c1 > c2:
                    img[i][j] = [0, 0, 0]
                else:
                    img[i][j] = [255, 255, 255]
        res_img.append(img)

    res_img = np.array(res_img)
    c = 0

    for i in tqdm(range(size), desc="Calculating y_pred"):
        img = res_img[i]
        for j in range(h):
            for l in range(w):
                b = img[j][l][0]
                if b == 0:
                    y_pred[c][0] = 0
                else:
                    y_pred[c][0] = 1
                c += 1

    c = 0

    for i in tqdm(range(size), desc="Calculating y_test"):
        img = gt[i]
        for j in range(h):
            for l in range(w):
                b = img[j][l][0]
                if b == 1:
                    y_test[c][0] = 0
                else:
                    y_test[c][0] = 1
                c += 1

    print(classification_report(y_test, y_pred))

    conf_mat = confusion_matrix(y_test, y_pred, labels=[0, 1])
    tp = np.diag(conf_mat)
    fp = np.sum(conf_mat, axis=0) - tp
    fn = np.sum(conf_mat, axis=1) - tp
    iou = tp / (tp + fp + fn + 1e-10)
    miou = np.mean(iou)

    print('mIoU:', miou)
    return

def dice_coef(y_true, y_pred):
    numerator = 2 * K.sum(y_true * y_pred, axis=(1, 2, 3))
    denominator = K.sum(y_true, axis=(1, 2, 3)) + K.sum(y_pred, axis=(1, 2, 3))
    dice_loss = 1 - (numerator + 1) / (denominator + 1)
    return dice_loss

def dice_coef_loss(y_true, y_pred):
    return 1.0 - dice_coef(y_true, y_pred)

def Prepare_data(path_train, path_gt, h, w, n_labels=2):
    target = cv2.imread("/content/drive/MyDrive/Colab_Notebooks/BHI_dataset/Target.png")
    imgs = []
    labels = []

    files_train = os.listdir(path_train)
    files_gt = os.listdir(path_gt)

    base_files_train = set([os.path.splitext(file)[0] for file in files_train])
    base_files_gt = set([os.path.splitext(file)[0] for file in files_gt])

    matching_files = list(set(base_files_train).intersection(base_files_gt))

    for file_base in tqdm(matching_files):
        original_img = cv2.imread(os.path.join(path_train, file_base + ".png"))
        mask = cv2.imread(os.path.join(path_gt, file_base + ".png"))

        resized_img = cv2.resize(original_img, (h, w))
        cn_img = Reinhard_method(target, resized_img)
        array_img = img_to_array(cn_img) / 255
        imgs.append(array_img)

        mask = cv2.resize(mask, (h, w))
        array_mask = create_label(mask, (h, w),h,w,2)
        labels.append(array_mask)
    imgs = np.array(imgs)
    labels = np.array(labels)
    return imgs, labels, matching_files

def Unet(input_size = (128,128,3)):

    inputs = tf.keras.Input(input_size)
    conv1 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(inputs)
    conv1=tf.keras.layers.BatchNormalization()(conv1)
    conv1 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv1)
    conv1=tf.keras.layers.BatchNormalization()(conv1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)

    conv2 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool1)
    conv2=tf.keras.layers.BatchNormalization()(conv2)
    conv2 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv2)
    conv2=tf.keras.layers.BatchNormalization()(conv2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)

    conv3 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool2)
    conv3=tf.keras.layers.BatchNormalization()(conv3)
    conv3 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv3)
    conv3=tf.keras.layers.BatchNormalization(name='b1')(conv3)
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)

    conv4 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool3)
    conv4=tf.keras.layers.BatchNormalization()(conv4)
    conv4 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv4)
    conv4=tf.keras.layers.BatchNormalization()(conv4)
    drop4 = Dropout(0.5)(conv4)
    pool4 = MaxPooling2D(pool_size=(2, 2))(drop4)

    conv5 = Conv2D(1024, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool4)
    conv5=tf.keras.layers.BatchNormalization()(conv5)
    conv5 = Conv2D(1024, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv5)
    conv5=tf.keras.layers.BatchNormalization()(conv5)
    drop5 =Dropout(0.5)(conv5)

    up6 = Conv2D(512, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(drop5))
    merge6 = tf.keras.layers.concatenate([conv4,up6],  axis = -1)
    conv6 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge6)
    conv6=tf.keras.layers.BatchNormalization()(conv6)
    conv6 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv6)
    conv6=tf.keras.layers.BatchNormalization()(conv6)

    up7 = Conv2D(256, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(conv6))
    merge7 = tf.keras.layers.concatenate([conv3,up7],axis = -1)
    conv7 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge7)
    conv7=tf.keras.layers.BatchNormalization()(conv7)
    conv7 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv7)
    conv7=tf.keras.layers.BatchNormalization()(conv7)

    up8 = Conv2D(128, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(conv7))
    merge8 = tf.keras.layers.concatenate([conv2,up8],axis = -1)
    conv8 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge8)
    conv8=tf.keras.layers.BatchNormalization()(conv8)
    conv8 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv8)
    conv8=tf.keras.layers.BatchNormalization()(conv8)

    up9 = Conv2D(64, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(conv8))
    merge9 = tf.keras.layers.concatenate([conv1,up9], axis = -1)
    conv9 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge9)
    conv9=tf.keras.layers.BatchNormalization()(conv9)
    conv9 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv9)
    conv9=tf.keras.layers.BatchNormalization()(conv9)

    conv10 = Conv2D(2, 1, activation = 'softmax')(conv9)
    model = Model(inputs = [inputs], outputs = [conv10])
    model.compile(optimizer=Adam(learning_rate=0.0001),loss="binary_crossentropy",metrics=["accuracy"])
    model.summary()
    return model

if __name__ == "__main__":
    path_train='/content/drive/MyDrive/Colab_Notebooks/BHI_dataset/Gt/'
    path_gt='/content/drive/MyDrive/Colab_Notebooks/BHI_dataset/Img/'

    h=256
    w=256

    print("Preparing and loading training data...")
    X,Y,filenames = Prepare_data(path_train,path_gt,h,w)
    print("Done Preparing training data...")

    nb_epoch = 50
    batch = 5
    n_labels = 2
    model=Unet((h,w,3))

    print('Model Compiled: OK.....')
    print("Opening model...")
    history=model.fit(x=X,y=Y,batch_size=batch, epochs=nb_epoch, verbose=1,validation_split=0.2)
    print("Model Fitting done...")
    model.save_weights('U-Net_50.hdf5')
    model.load_weights('U-Net_50.hdf5')

    fig=plt.figure()
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('Model accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()
    fig.savefig("U-Net_accuracy.png")
    # Summarize history for loss
    fig=plt.figure()
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('Model loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()
    fig.savefig("U-Net_loss.png")

    path_test_gt='/content/drive/MyDrive/Colab_Notebooks/BHI_dataset/Img-test/'
    path_test='/content/drive/MyDrive/Colab_Notebooks/BHI_dataset/Gt-test/'
    print("Preparing testing data...")
    test_data,gt,filenames = Prepare_data(path_test,path_test_gt,h,w)
    output = model.predict(test_data,batch_size=batch, verbose=1)

    print("Calculating metrics...")
    Calculate_metrics(output,gt,h,w)

for i in tqdm(range(len(test_data))):
    Write_output_path = "/content/drive/MyDrive/Colab_Notebooks/BHI_dataset/Unet/Results_7/Img_" + filenames[i] + ".png"
    out = output[i]
    img = test_data[i]

    for j in range(h):
        for p in range(w):
            if out[j][p][0] > out[j][p][1]:
                img[j][p] = [0, 0, 0]
            else:
                img[j][p] = [255, 255, 255]
        cv2.imwrite(Write_output_path, img)
# Out:
# Preparing and loading training data...
# 100%|██████████| 340/340 [02:01<00:00,  2.79it/s]
# Done Preparing training data...
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_4 (InputLayer)        [(None, 256, 256, 3)]        0         []
#
#  conv2d_69 (Conv2D)          (None, 256, 256, 64)         1792      ['input_4[0][0]']
#
#  batch_normalization_51 (Ba  (None, 256, 256, 64)         256       ['conv2d_69[0][0]']
#  tchNormalization)
#
#  conv2d_70 (Conv2D)          (None, 256, 256, 64)         36928     ['batch_normalization_51[0][0]
#                                                                     ']
#
#  batch_normalization_52 (Ba  (None, 256, 256, 64)         256       ['conv2d_70[0][0]']
#  tchNormalization)
#
#  max_pooling2d_12 (MaxPooli  (None, 128, 128, 64)         0         ['batch_normalization_52[0][0]
#  ng2D)                                                              ']
#
#  conv2d_71 (Conv2D)          (None, 128, 128, 128)        73856     ['max_pooling2d_12[0][0]']
#
#  batch_normalization_53 (Ba  (None, 128, 128, 128)        512       ['conv2d_71[0][0]']
#  tchNormalization)
#
#  conv2d_72 (Conv2D)          (None, 128, 128, 128)        147584    ['batch_normalization_53[0][0]
#                                                                     ']
#
#  batch_normalization_54 (Ba  (None, 128, 128, 128)        512       ['conv2d_72[0][0]']
#  tchNormalization)
#
#  max_pooling2d_13 (MaxPooli  (None, 64, 64, 128)          0         ['batch_normalization_54[0][0]
#  ng2D)                                                              ']
#
#  conv2d_73 (Conv2D)          (None, 64, 64, 256)          295168    ['max_pooling2d_13[0][0]']
#
#  batch_normalization_55 (Ba  (None, 64, 64, 256)          1024      ['conv2d_73[0][0]']
#  tchNormalization)
#
#  conv2d_74 (Conv2D)          (None, 64, 64, 256)          590080    ['batch_normalization_55[0][0]
#                                                                     ']
#
#  b1 (BatchNormalization)     (None, 64, 64, 256)          1024      ['conv2d_74[0][0]']
#
#  max_pooling2d_14 (MaxPooli  (None, 32, 32, 256)          0         ['b1[0][0]']
#  ng2D)
#
#  conv2d_75 (Conv2D)          (None, 32, 32, 512)          1180160   ['max_pooling2d_14[0][0]']
#
#  batch_normalization_56 (Ba  (None, 32, 32, 512)          2048      ['conv2d_75[0][0]']
#  tchNormalization)
#
#  conv2d_76 (Conv2D)          (None, 32, 32, 512)          2359808   ['batch_normalization_56[0][0]
#                                                                     ']
#
#  batch_normalization_57 (Ba  (None, 32, 32, 512)          2048      ['conv2d_76[0][0]']
#  tchNormalization)
#
#  dropout_6 (Dropout)         (None, 32, 32, 512)          0         ['batch_normalization_57[0][0]
#                                                                     ']
#
#  max_pooling2d_15 (MaxPooli  (None, 16, 16, 512)          0         ['dropout_6[0][0]']
#  ng2D)
#
#  conv2d_77 (Conv2D)          (None, 16, 16, 1024)         4719616   ['max_pooling2d_15[0][0]']
#
#  batch_normalization_58 (Ba  (None, 16, 16, 1024)         4096      ['conv2d_77[0][0]']
#  tchNormalization)
#
#  conv2d_78 (Conv2D)          (None, 16, 16, 1024)         9438208   ['batch_normalization_58[0][0]
#                                                                     ']
#
#  batch_normalization_59 (Ba  (None, 16, 16, 1024)         4096      ['conv2d_78[0][0]']
#  tchNormalization)
#
#  dropout_7 (Dropout)         (None, 16, 16, 1024)         0         ['batch_normalization_59[0][0]
#                                                                     ']
#
#  up_sampling2d_12 (UpSampli  (None, 32, 32, 1024)         0         ['dropout_7[0][0]']
#  ng2D)
#
#  conv2d_79 (Conv2D)          (None, 32, 32, 512)          2097664   ['up_sampling2d_12[0][0]']
#
#  concatenate_12 (Concatenat  (None, 32, 32, 1024)         0         ['batch_normalization_57[0][0]
#  e)                                                                 ',
#                                                                      'conv2d_79[0][0]']
#
#  conv2d_80 (Conv2D)          (None, 32, 32, 512)          4719104   ['concatenate_12[0][0]']
#
#  batch_normalization_60 (Ba  (None, 32, 32, 512)          2048      ['conv2d_80[0][0]']
#  tchNormalization)
#
#  conv2d_81 (Conv2D)          (None, 32, 32, 512)          2359808   ['batch_normalization_60[0][0]
#                                                                     ']
#
#  batch_normalization_61 (Ba  (None, 32, 32, 512)          2048      ['conv2d_81[0][0]']
#  tchNormalization)
#
#  up_sampling2d_13 (UpSampli  (None, 64, 64, 512)          0         ['batch_normalization_61[0][0]
#  ng2D)                                                              ']
#
#  conv2d_82 (Conv2D)          (None, 64, 64, 256)          524544    ['up_sampling2d_13[0][0]']
#
#  concatenate_13 (Concatenat  (None, 64, 64, 512)          0         ['b1[0][0]',
#  e)                                                                  'conv2d_82[0][0]']
#
#  conv2d_83 (Conv2D)          (None, 64, 64, 256)          1179904   ['concatenate_13[0][0]']
#
#  batch_normalization_62 (Ba  (None, 64, 64, 256)          1024      ['conv2d_83[0][0]']
#  tchNormalization)
#
#  conv2d_84 (Conv2D)          (None, 64, 64, 256)          590080    ['batch_normalization_62[0][0]
#                                                                     ']
#
#  batch_normalization_63 (Ba  (None, 64, 64, 256)          1024      ['conv2d_84[0][0]']
#  tchNormalization)
#
#  up_sampling2d_14 (UpSampli  (None, 128, 128, 256)        0         ['batch_normalization_63[0][0]
#  ng2D)                                                              ']
#
#  conv2d_85 (Conv2D)          (None, 128, 128, 128)        131200    ['up_sampling2d_14[0][0]']
#
#  concatenate_14 (Concatenat  (None, 128, 128, 256)        0         ['batch_normalization_54[0][0]
#  e)                                                                 ',
#                                                                      'conv2d_85[0][0]']
#
#  conv2d_86 (Conv2D)          (None, 128, 128, 128)        295040    ['concatenate_14[0][0]']
#
#  batch_normalization_64 (Ba  (None, 128, 128, 128)        512       ['conv2d_86[0][0]']
#  tchNormalization)
#
#  conv2d_87 (Conv2D)          (None, 128, 128, 128)        147584    ['batch_normalization_64[0][0]
#                                                                     ']
#
#  batch_normalization_65 (Ba  (None, 128, 128, 128)        512       ['conv2d_87[0][0]']
#  tchNormalization)
#
#  up_sampling2d_15 (UpSampli  (None, 256, 256, 128)        0         ['batch_normalization_65[0][0]
#  ng2D)                                                              ']
#
#  conv2d_88 (Conv2D)          (None, 256, 256, 64)         32832     ['up_sampling2d_15[0][0]']
#
#  concatenate_15 (Concatenat  (None, 256, 256, 128)        0         ['batch_normalization_52[0][0]
#  e)                                                                 ',
#                                                                      'conv2d_88[0][0]']
#
#  conv2d_89 (Conv2D)          (None, 256, 256, 64)         73792     ['concatenate_15[0][0]']
#
#  batch_normalization_66 (Ba  (None, 256, 256, 64)         256       ['conv2d_89[0][0]']
#  tchNormalization)
#
#  conv2d_90 (Conv2D)          (None, 256, 256, 64)         36928     ['batch_normalization_66[0][0]
#                                                                     ']
#
#  batch_normalization_67 (Ba  (None, 256, 256, 64)         256       ['conv2d_90[0][0]']
#  tchNormalization)
#
#  conv2d_91 (Conv2D)          (None, 256, 256, 2)          130       ['batch_normalization_67[0][0]
#                                                                     ']
#
# ==================================================================================================
# Total params: 31055362 (118.47 MB)
# Trainable params: 31043586 (118.42 MB)
# Non-trainable params: 11776 (46.00 KB)
# __________________________________________________________________________________________________
# Model Compiled: OK.....
# Opening model...
# Epoch 1/50
# 55/55 [==============================] - 39s 512ms/step - loss: 0.5453 - accuracy: 0.7396 - val_loss: 2.0092 - val_accuracy: 0.5075
# Epoch 2/50
# 55/55 [==============================] - 27s 487ms/step - loss: 0.4084 - accuracy: 0.8230 - val_loss: 1.0170 - val_accuracy: 0.6044
# Epoch 3/50
# 55/55 [==============================] - 28s 513ms/step - loss: 0.3356 - accuracy: 0.8575 - val_loss: 1.5422 - val_accuracy: 0.5024
# Epoch 4/50
# 55/55 [==============================] - 28s 509ms/step - loss: 0.3034 - accuracy: 0.8712 - val_loss: 0.7341 - val_accuracy: 0.6159
# Epoch 5/50
# 55/55 [==============================] - 29s 525ms/step - loss: 0.2662 - accuracy: 0.8889 - val_loss: 0.4573 - val_accuracy: 0.7611
# Epoch 6/50
# 55/55 [==============================] - 29s 521ms/step - loss: 0.2312 - accuracy: 0.9047 - val_loss: 0.3820 - val_accuracy: 0.8385
# Epoch 7/50
# 55/55 [==============================] - 28s 508ms/step - loss: 0.2054 - accuracy: 0.9177 - val_loss: 0.4390 - val_accuracy: 0.8388
# Epoch 8/50
# 55/55 [==============================] - 28s 507ms/step - loss: 0.1666 - accuracy: 0.9327 - val_loss: 0.3864 - val_accuracy: 0.8610
# Epoch 9/50
# 55/55 [==============================] - 29s 521ms/step - loss: 0.1751 - accuracy: 0.9297 - val_loss: 0.3541 - val_accuracy: 0.8697
# Epoch 10/50
# 55/55 [==============================] - 29s 522ms/step - loss: 0.1719 - accuracy: 0.9316 - val_loss: 0.3155 - val_accuracy: 0.8721
# Epoch 11/50
# 55/55 [==============================] - 28s 506ms/step - loss: 0.1431 - accuracy: 0.9436 - val_loss: 0.3985 - val_accuracy: 0.8737
# Epoch 12/50
# 55/55 [==============================] - 29s 523ms/step - loss: 0.1367 - accuracy: 0.9483 - val_loss: 0.2250 - val_accuracy: 0.9120
# Epoch 13/50
# 55/55 [==============================] - 29s 522ms/step - loss: 0.1167 - accuracy: 0.9554 - val_loss: 0.2556 - val_accuracy: 0.9118
# Epoch 14/50
# 55/55 [==============================] - 28s 506ms/step - loss: 0.1351 - accuracy: 0.9488 - val_loss: 0.2142 - val_accuracy: 0.9178
# Epoch 15/50
# 55/55 [==============================] - 29s 522ms/step - loss: 0.1260 - accuracy: 0.9527 - val_loss: 0.2284 - val_accuracy: 0.9102
# Epoch 16/50
# 55/55 [==============================] - 28s 507ms/step - loss: 0.1069 - accuracy: 0.9603 - val_loss: 0.3838 - val_accuracy: 0.8674
# Epoch 17/50
# 55/55 [==============================] - 29s 523ms/step - loss: 0.1189 - accuracy: 0.9548 - val_loss: 0.3467 - val_accuracy: 0.9028
# Epoch 18/50
# 55/55 [==============================] - 28s 506ms/step - loss: 0.1063 - accuracy: 0.9603 - val_loss: 0.2736 - val_accuracy: 0.9040
# Epoch 19/50
# 55/55 [==============================] - 29s 524ms/step - loss: 0.0854 - accuracy: 0.9681 - val_loss: 0.1989 - val_accuracy: 0.9318
# Epoch 20/50
# 55/55 [==============================] - 29s 522ms/step - loss: 0.1150 - accuracy: 0.9563 - val_loss: 0.3676 - val_accuracy: 0.8886
# Epoch 21/50
# 55/55 [==============================] - 29s 521ms/step - loss: 0.0974 - accuracy: 0.9639 - val_loss: 0.2649 - val_accuracy: 0.9143
# Epoch 22/50
# 55/55 [==============================] - 29s 523ms/step - loss: 0.0816 - accuracy: 0.9693 - val_loss: 0.2048 - val_accuracy: 0.9370
# Epoch 23/50
# 55/55 [==============================] - 29s 522ms/step - loss: 0.0685 - accuracy: 0.9741 - val_loss: 0.2001 - val_accuracy: 0.9352
# Epoch 24/50
# 55/55 [==============================] - 28s 507ms/step - loss: 0.0625 - accuracy: 0.9765 - val_loss: 0.1940 - val_accuracy: 0.9338
# Epoch 25/50
# 55/55 [==============================] - 29s 523ms/step - loss: 0.0562 - accuracy: 0.9785 - val_loss: 0.1829 - val_accuracy: 0.9414
# Epoch 26/50
# 55/55 [==============================] - 28s 507ms/step - loss: 0.0500 - accuracy: 0.9810 - val_loss: 0.1815 - val_accuracy: 0.9432
# Epoch 27/50
# 55/55 [==============================] - 28s 506ms/step - loss: 0.0482 - accuracy: 0.9817 - val_loss: 0.2679 - val_accuracy: 0.9273
# Epoch 28/50
# 55/55 [==============================] - 28s 506ms/step - loss: 0.0490 - accuracy: 0.9813 - val_loss: 0.2565 - val_accuracy: 0.9307
# Epoch 29/50
# 55/55 [==============================] - 28s 506ms/step - loss: 0.0558 - accuracy: 0.9798 - val_loss: 0.2886 - val_accuracy: 0.9167
# Epoch 30/50
# 55/55 [==============================] - 29s 522ms/step - loss: 0.0668 - accuracy: 0.9752 - val_loss: 0.2021 - val_accuracy: 0.9365
# Epoch 31/50
# 55/55 [==============================] - 29s 522ms/step - loss: 0.0532 - accuracy: 0.9794 - val_loss: 0.2305 - val_accuracy: 0.9349
# Epoch 32/50
# 55/55 [==============================] - 29s 522ms/step - loss: 0.0680 - accuracy: 0.9738 - val_loss: 0.1892 - val_accuracy: 0.9422
# Epoch 33/50
# 55/55 [==============================] - 29s 522ms/step - loss: 0.0724 - accuracy: 0.9733 - val_loss: 1.4847 - val_accuracy: 0.8858
# Epoch 34/50
# 55/55 [==============================] - 29s 523ms/step - loss: 0.0728 - accuracy: 0.9725 - val_loss: 0.4029 - val_accuracy: 0.9046
# Epoch 35/50
# 55/55 [==============================] - 29s 523ms/step - loss: 0.0480 - accuracy: 0.9819 - val_loss: 0.3257 - val_accuracy: 0.9196
# Epoch 36/50
# 55/55 [==============================] - 28s 506ms/step - loss: 0.0423 - accuracy: 0.9833 - val_loss: 0.3115 - val_accuracy: 0.9238
# Epoch 37/50
# 55/55 [==============================] - 29s 522ms/step - loss: 0.0498 - accuracy: 0.9809 - val_loss: 0.2951 - val_accuracy: 0.9210
# Epoch 38/50
# 55/55 [==============================] - 28s 507ms/step - loss: 0.0411 - accuracy: 0.9843 - val_loss: 0.2554 - val_accuracy: 0.9300
# Epoch 39/50
# 55/55 [==============================] - 28s 507ms/step - loss: 0.0380 - accuracy: 0.9851 - val_loss: 0.3924 - val_accuracy: 0.9113
# Epoch 40/50
# 55/55 [==============================] - 29s 523ms/step - loss: 0.0362 - accuracy: 0.9860 - val_loss: 0.3328 - val_accuracy: 0.9111
# Epoch 41/50
# 55/55 [==============================] - 29s 522ms/step - loss: 0.0371 - accuracy: 0.9858 - val_loss: 0.2635 - val_accuracy: 0.9349
# Epoch 42/50
# 55/55 [==============================] - 29s 521ms/step - loss: 0.0334 - accuracy: 0.9868 - val_loss: 0.2427 - val_accuracy: 0.9398
# Epoch 43/50
# 55/55 [==============================] - 29s 522ms/step - loss: 0.0307 - accuracy: 0.9880 - val_loss: 0.2732 - val_accuracy: 0.9356
# Epoch 44/50
# 55/55 [==============================] - 29s 523ms/step - loss: 0.0291 - accuracy: 0.9885 - val_loss: 0.2312 - val_accuracy: 0.9432
# Epoch 45/50
# 55/55 [==============================] - 29s 523ms/step - loss: 0.0268 - accuracy: 0.9894 - val_loss: 0.2442 - val_accuracy: 0.9396
# Epoch 46/50
# 55/55 [==============================] - 28s 507ms/step - loss: 0.0290 - accuracy: 0.9890 - val_loss: 0.2835 - val_accuracy: 0.9328
# Epoch 47/50
# 55/55 [==============================] - 29s 523ms/step - loss: 0.0905 - accuracy: 0.9700 - val_loss: 0.3161 - val_accuracy: 0.9113
# Epoch 48/50
# 55/55 [==============================] - 28s 506ms/step - loss: 0.0577 - accuracy: 0.9774 - val_loss: 0.2465 - val_accuracy: 0.9303
# Epoch 49/50
# 55/55 [==============================] - 28s 506ms/step - loss: 0.0409 - accuracy: 0.9840 - val_loss: 0.2606 - val_accuracy: 0.9310
# Epoch 50/50
# 55/55 [==============================] - 29s 522ms/step - loss: 0.0593 - accuracy: 0.9776 - val_loss: 0.5141 - val_accuracy: 0.9017
# Model Fitting done...
# Preparing testing data...
# 100%|██████████| 320/320 [01:54<00:00,  2.79it/s]
# 64/64 [==============================] - 8s 117ms/step
# Calculating metrics...
# Processing images: 100%|██████████| 320/320 [00:35<00:00,  9.06it/s]
# Calculating y_pred: 100%|██████████| 320/320 [00:16<00:00, 19.64it/s]
# Calculating y_test: 100%|██████████| 320/320 [00:16<00:00, 19.66it/s]
#               precision    recall  f1-score   support
#
#          0.0       0.76      0.93      0.84   9903630
#          1.0       0.92      0.74      0.82  11067890
#
#     accuracy                           0.83  20971520
#    macro avg       0.84      0.83      0.83  20971520
# weighted avg       0.85      0.83      0.83  20971520
#
# mIoU: 0.7074918148875047
# 100%|██████████| 320/320 [07:31<00:00,  1.41s/it]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
